# %% [markdown]
# ## Consulta

# %%
import pyodbc
import pandas as pd

# Parámetros de conexión
server = '172.16.1.33'
database = 'ZOHO'

try:
    conn = pyodbc.connect(
        'DRIVER={ODBC Driver 17 for SQL Server};'
        f'SERVER={server};'
        f'DATABASE={database};'
        'Trusted_Connection=yes;'
    )

    # Consulta con filtro por fecha
    query = """
 select 
cz.Conversation_ID
,tc.Id_url
,tc.Transcripción
,cz.Phone_Number
,Initiated_Time

,co.email

,Departamento
,tc.Departamento
,cz.Attender
,co.Operator_ID
,CONVERT(date, TRY_CONVERT(datetime, tc.[Hora_de_creación], 103)) AS FechaCreacion
,CONVERT(time(7),TRY_CONVERT(datetime, tc.[Hora_de_creación], 103)) AS hora

from [CRM].[Transcripciones_de_chat] as tc
inner join [CRM].[Conversations_Zoho_SalesIQ_] as cz on cz.Conversation_ID = tc.Id_url
inner join CRM.Operators_Zoho_SalesIQ_ as co on co.Operator_ID = cz.Attender
where tc.Departamento != 'SERVICIO'
and TRY_CONVERT(datetime, tc.[Hora_de_creación], 103) >= '2025-09-23T00:00:00'--fecha de traer los chats


order by tc.[Hora_de_creación] desc
    
    """

    # Ejecutar y guardar en DataFrame
    df4 = pd.read_sql(query, conn)
    print(df4)

    conn.close()

except Exception as e:
    print("❌ Error en la conexión o consulta:", e)
# Out:
# C:\Users\haider_bello\AppData\Local\Temp\ipykernel_17552\4236327809.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4 = pd.read_sql(query, conn)
#          Conversation_ID              Id_url  \
# 0     534099000030000821  534099000030000821
# 1     534099000029096117  534099000029096117
# 2     534099000029613505  534099000029613505
# 3     534099000029654773  534099000029654773
# 4     534099000030058981  534099000030058981
# ...                  ...                 ...
# 6451  534099000029305993  534099000029305993
# 6452  534099000017018121  534099000017018121
# 6453  534099000030308421  534099000030308421
# 6454  534099000029950445  534099000029950445
# 6455  534099000030331227  534099000030331227
#
#                                           Transcripción   Phone_Number  \
# 0     Hola\n#Alexsandra De Alba E : Hola\n#Contact N...  +573226674838
# 1     Hola, vengo de inscripciones y quiero encender...   573052960258
# 2     https://fb.me/3x0oLNDtc \n\n¡Hola! ? Me intere...   573208330691
# 3     https://www.instagram.com/p/DN80J3fgNe6/ \n\n¡...  +573176725914
# 4     https://fb.me/8RVJVdVzd \n\n¡Hola! ? Me intere...  +573107719695
# ...                                                 ...            ...
# 6451  https://fb.me/jL46OcxfW \n\n¡Hola! ? Me intere...   573145699794
# 6452  Buenas tardes\n#Viviana : Buenas tardes\n#CUND...     3106569592
# 6453  https://www.instagram.com/p/DOWaG17gI6s/ \n\n¡...  +573127143184
# 6454  https://fb.me/5x8weEIxD \n\n¡Hola! ? Me intere...  +573178334280
# 6455  Hola, vengo de inscripciones y quiero encender...  +573196104819
#
#         Initiated_Time                          email       Departamento  \
# 0     19-09-2025 10:32  jairo_valderramaca@cun.edu.co  Pregrado Whatsapp
# 1     29-09-2025 13:24      jose_jimenezro@cun.edu.co  Pregrado Whatsapp
# 2     07-09-2025 07:13         bryan_ortiz@cun.edu.co  Pregrado Whatsapp
# 3     09-09-2025 09:57   jameson_rodriguez@cun.edu.co  Pregrado Whatsapp
# 4     22-09-2025 11:12    brayan_cespedesp@cun.edu.co  Pregrado Whatsapp
# ...                ...                            ...                ...
# 6451  28-08-2025 18:32      hector_quiroga@cun.edu.co  Pregrado Whatsapp
# 6452  29-09-2025 07:55                           None      Vinculaciones
# 6453  29-09-2025 12:30   ricardo_alvarezro@cun.edu.co  Pregrado Whatsapp
# 6454  18-09-2025 07:35       karen_penagos@cun.edu.co  Pregrado Whatsapp
# 6455  29-09-2025 20:07         bryan_ortiz@cun.edu.co  Pregrado Whatsapp
#
#            Departamento            Attender         Operator_ID FechaCreacion  \
# 0     Pregrado Whatsapp  534099000027527219  534099000027527219    2025-09-30
# 1     Pregrado Whatsapp  534099000028077219  534099000028077219    2025-09-30
# 2     Pregrado Whatsapp  534099000023841915  534099000023841915    2025-09-30
# 3     Pregrado Whatsapp  534099000023841985  534099000023841985    2025-09-30
# 4     Pregrado Whatsapp  534099000028075947  534099000028075947    2025-09-30
# ...                 ...                 ...                 ...           ...
# 6451  Pregrado Whatsapp  534099000028840745  534099000028840745    2025-10-01
# 6452      Vinculaciones  534099000005406045  534099000005406045    2025-10-01
# 6453  Pregrado Whatsapp  534099000025343903  534099000025343903    2025-10-01
# 6454  Pregrado Whatsapp  534099000025651043  534099000025651043    2025-10-01
# 6455  Pregrado Whatsapp  534099000023841915  534099000023841915    2025-10-01
#
#           hora
# 0     22:05:00
# 1     22:05:00
# 2     21:40:00
# 3     21:32:00
# 4     21:29:00
# ...        ...
# 6451  07:51:00
# 6452  07:36:00
# 6453  06:14:00
# 6454  06:11:00
# 6455  06:10:00
#
# [6456 rows x 12 columns]

# %%
df4
# Out:
#          Conversation_ID              Id_url  \
# 0     534099000030000821  534099000030000821
# 1     534099000029096117  534099000029096117
# 2     534099000029613505  534099000029613505
# 3     534099000029654773  534099000029654773
# 4     534099000030058981  534099000030058981
# ...                  ...                 ...
# 6451  534099000029305993  534099000029305993
# 6452  534099000017018121  534099000017018121
# 6453  534099000030308421  534099000030308421
# 6454  534099000029950445  534099000029950445
# 6455  534099000030331227  534099000030331227
#
#                                           Transcripción   Phone_Number  \
# 0     Hola\n#Alexsandra De Alba E : Hola\n#Contact N...  +573226674838
# 1     Hola, vengo de inscripciones y quiero encender...   573052960258
# 2     https://fb.me/3x0oLNDtc \n\n¡Hola! ? Me intere...   573208330691
# 3     https://www.instagram.com/p/DN80J3fgNe6/ \n\n¡...  +573176725914
# 4     https://fb.me/8RVJVdVzd \n\n¡Hola! ? Me intere...  +573107719695
# ...                                                 ...            ...
# 6451  https://fb.me/jL46OcxfW \n\n¡Hola! ? Me intere...   573145699794
# 6452  Buenas tardes\n#Viviana : Buenas tardes\n#CUND...     3106569592
# 6453  https://www.instagram.com/p/DOWaG17gI6s/ \n\n¡...  +573127143184
# 6454  https://fb.me/5x8weEIxD \n\n¡Hola! ? Me intere...  +573178334280
# 6455  Hola, vengo de inscripciones y quiero encender...  +573196104819
#
#         Initiated_Time                          email       Departamento  \
# 0     19-09-2025 10:32  jairo_valderramaca@cun.edu.co  Pregrado Whatsapp
# 1     29-09-2025 13:24      jose_jimenezro@cun.edu.co  Pregrado Whatsapp
# 2     07-09-2025 07:13         bryan_ortiz@cun.edu.co  Pregrado Whatsapp
# 3     09-09-2025 09:57   jameson_rodriguez@cun.edu.co  Pregrado Whatsapp
# 4     22-09-2025 11:12    brayan_cespedesp@cun.edu.co  Pregrado Whatsapp
# ...                ...                            ...                ...
# 6451  28-08-2025 18:32      hector_quiroga@cun.edu.co  Pregrado Whatsapp
# 6452  29-09-2025 07:55                           None      Vinculaciones
# 6453  29-09-2025 12:30   ricardo_alvarezro@cun.edu.co  Pregrado Whatsapp
# 6454  18-09-2025 07:35       karen_penagos@cun.edu.co  Pregrado Whatsapp
# 6455  29-09-2025 20:07         bryan_ortiz@cun.edu.co  Pregrado Whatsapp
#
#            Departamento            Attender         Operator_ID FechaCreacion  \
# 0     Pregrado Whatsapp  534099000027527219  534099000027527219    2025-09-30
# 1     Pregrado Whatsapp  534099000028077219  534099000028077219    2025-09-30
# 2     Pregrado Whatsapp  534099000023841915  534099000023841915    2025-09-30
# 3     Pregrado Whatsapp  534099000023841985  534099000023841985    2025-09-30
# 4     Pregrado Whatsapp  534099000028075947  534099000028075947    2025-09-30
# ...                 ...                 ...                 ...           ...
# 6451  Pregrado Whatsapp  534099000028840745  534099000028840745    2025-10-01
# 6452      Vinculaciones  534099000005406045  534099000005406045    2025-10-01
# 6453  Pregrado Whatsapp  534099000025343903  534099000025343903    2025-10-01
# 6454  Pregrado Whatsapp  534099000025651043  534099000025651043    2025-10-01
# 6455  Pregrado Whatsapp  534099000023841915  534099000023841915    2025-10-01
#
#           hora
# 0     22:05:00
# 1     22:05:00
# 2     21:40:00
# 3     21:32:00
# 4     21:29:00
# ...        ...
# 6451  07:51:00
# 6452  07:36:00
# 6453  06:14:00
# 6454  06:11:00
# 6455  06:10:00
#
# [6456 rows x 12 columns]

# %%
# -*- coding: utf-8 -*-
"""
Limpia chats eliminando CUNDigital/Channel User, analiza keywords y sentimiento,
y enriquece con cédula del asesor vía SQL (dbo.Planta_Activa: box_mail -> Identificacion).

- Entrada: archivo .xlsx/.csv (INPUT_SRC) o df4 en memoria (si INPUT_SRC=None)
- Salida: DataFrame con columnas tipo "ventas" y guardado opcional en OUTPUT_PATH
"""

import pandas as pd
import re
import unicodedata
import html
from datetime import datetime, time
from pathlib import Path
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
import pyodbc  # ← necesario para cargar cédulas

# ===================== CONFIGURA AQUÍ =====================
INPUT_SRC   = df4           # ← ruta .xlsx/.csv o None para usar df4 en memoria
OUTPUT_PATH = r"C:\visual\chats\resultado01-10-2025.xlsx"     # ← nombre del execel como va a salir
TIPO_POR_DEFECTO = "chats"

# --- Parámetros SQL para cédulas (Planta_Activa) ---
USE_SQL_CEDULAS = True
SQL_SERVER   = '172.16.1.33'
SQL_DATABASE = 'CUN_REPOSITORIO'
SQL_USER     = 'haider_bello'
SQL_PASSWORD = 'Cun040825"#$&/$*'  # contiene comillas → déjalo entre comillas simples

# ===================== Helpers I/O =====================
def load_input(src_or_df):
    """Acepta DataFrame o ruta (.xlsx/.csv). Si src_or_df=None, intenta usar df4 en memoria."""
    if isinstance(src_or_df, pd.DataFrame):
        return src_or_df.copy()
    if src_or_df is None:
        try:
            return df4.copy()  # noqa: F821
        except NameError:
            raise ValueError("No se pasó INPUT_SRC ni existe df4 en memoria.")
    p = Path(src_or_df)
    if not p.exists():
        raise FileNotFoundError(f"No existe el archivo: {p}")
    ext = p.suffix.lower()
    if ext in (".xlsx", ".xls"):
        return pd.read_excel(p)
    if ext == ".csv":
        return pd.read_csv(p)
    raise ValueError(f"Extensión no soportada: {ext}. Usa .xlsx/.xls/.csv o pasa un DataFrame.")

def save_output(df: pd.DataFrame, out_path):
    """
    Acepta carpeta o archivo:
    - Si out_path es carpeta o no tiene extensión -> crea nombre por defecto resultado_YYYYmmdd_%H%M.xlsx
    - Si no puede escribir XLSX, guarda CSV al mismo lado.
    """
    if not out_path:
        print("ℹ️ OUTPUT_PATH=None → no se guarda archivo.")
        return
    p = Path(out_path)
    if (p.exists() and p.is_dir()) or (p.suffix == ""):
        if p.suffix == "" and not p.exists() and p.parent.exists() and not p.parent.suffix:
            p = p / f"resultado_{datetime.now().strftime('%Y%m%d_%H%M')}.xlsx"
        elif p.exists() and p.is_dir():
            p = p / f"resultado_{datetime.now().strftime('%Y%m%d_%H%M')}.xlsx"
        else:
            p = p.with_suffix(".xlsx")
    p.parent.mkdir(parents=True, exist_ok=True)
    try:
        df.to_excel(p, index=False)
        print(f"✅ Guardado Excel en: {p}")
    except Exception as e:
        alt = p.with_suffix(".csv")
        df.to_csv(alt, index=False, encoding="utf-8-sig")
        print(f"⚠️ No se pudo escribir XLSX ({e}). Guardado CSV en: {alt}")

# ===================== Limpieza (sin #Contact) =====================
SPEAKER_LINE_RX = re.compile(r"^\s*#?\s*([^\n:]+?)\s*:\s*(.*)$")
BOT_NAMES = {
    "cun digital", "cundigital", "cun bot", "chatbot", "chat bot",
    "asistente virtual", "sistema", "system", "ivr", "virtual assistant",
    "channel user"
}

def _html_unescape(txt: str) -> str:
    return html.unescape(txt) if isinstance(txt, str) else txt

def _quitar_acentos(s: str) -> str:
    if not isinstance(s, str): return s
    return "".join(c for c in unicodedata.normalize("NFD", s) if unicodedata.category(c) != "Mn")

def _norm_name(name: str) -> str:
    n = _quitar_acentos(name).strip().lower()
    n = re.sub(r"\s+", " ", n)
    return n

def _is_bot_speaker(speaker: str) -> bool:
    return _norm_name(speaker) in BOT_NAMES

def _split_turns(text: str):
    """Devuelve [(speaker, content)] a partir de líneas '#Nombre : texto'."""
    if not isinstance(text, str) or not text.strip():
        return []
    t = _html_unescape(text)
    turns, current_speaker, current_lines = [], None, []
    for line in t.splitlines():
        m = SPEAKER_LINE_RX.match(line)
        if m:
            if current_speaker is not None:
                turns.append((current_speaker, "\n".join(current_lines).rstrip()))
            current_speaker = m.group(1).strip()
            first_line = m.group(2).rstrip()
            current_lines = [first_line] if first_line != "" else []
        else:
            if current_speaker is not None:
                current_lines.append(line.rstrip())
    if current_speaker is not None:
        turns.append((current_speaker, "\n".join(current_lines).rstrip()))
    return turns

def limpiar_sin_cundigital(text: str) -> str:
    """Elimina turnos de speakers BOT (CUNDigital/Channel User/etc.) en toda la celda."""
    if not isinstance(text, str) or not text.strip():
        return ""
    turns = _split_turns(text)
    if not turns:
        return ""
    kept = []
    for speaker, content in turns:
        if _is_bot_speaker(speaker):
            continue
        content = (content or "").strip()
        kept.append(f"#{speaker} : {content}" if content else f"#{speaker} :")
    cleaned = "\n".join(kept).strip()
    cleaned = re.sub(r"\n{3,}", "\n\n", cleaned)
    return cleaned

def pick_text_column_for_clean(df: pd.DataFrame) -> str:
    prefer = ["Transcripción", "Transcripcion"]
    fallback = ["Transcripción_limpia", "Transcripcion_limpia", "Transcripción_limpia_v2", "Transcripcion_limpia_v2"]
    for c in prefer:
        if c in df.columns: return c
    for c in fallback:
        if c in df.columns: return c
    for c in df.columns:
        if "transcripcion" in _quitar_acentos(str(c)).strip().lower():
            return c
    raise KeyError("No encuentro la columna de transcripción (ej. 'Transcripción').")

def limpiar_df4(df4: pd.DataFrame, dest_col: str = "Transcripción_limpia_v2") -> pd.DataFrame:
    base_col = pick_text_column_for_clean(df4)
    df = df4.copy()
    df[dest_col] = df[base_col].fillna("").astype(str).map(limpiar_sin_cundigital)
    return df

# ===================== Diccionarios / Requisitos =====================
diccionarios_keywords = {
    "saludo": {
        "alo","hola","buenos dias","buenas tardes","buenas noches","digame","si","quien habla","con quien hablo",
        "quien llama","de parte de quien","le puedo ayudar en algo","en que le puedo servir","que desea","que necesita",
        "habla con","soy","aqui","departamento de","le atiende","si le escucho","le oigo","adelante","te escucho","todo bien",
        "que tal","como le va","como te va","que cuentas","que hay de nuevo","que pasa","que me cuentas","a quien busca",
        "a quien desea hablar","con quien gustaria hablar","con quien le gustaria hablar","con quien te gustaria hablar","a quien busca por favor",
        "podria decirme con quien desea hablar","hablo con","si soy yo","en que puedo ayudarle","si habla con el","si habla con ella","si que necesita",
        "un segundo por favor","espere un momentito","ya le pongo","me puede repetir su nombre por favor","podria deletrear su nombre","cual es su apellido",
        "de que empresa llama","cual es su extension","no le escucho bien podria hablar mas alto","se oye entrecortado","puede repetir",
        "entendio","esta claro","perfecto","muy bien","de acuerdo","entendido","gracias","muchas gracias","a usted","con gusto","que tenga un buen dia",
        "que tenga buena tarde","que tenga buena noche","igualmente","hasta luego","adios","nos vemos","que le vaya bien","saludos","un placer atenderle",
        "gracias por su tiempo","nombre","area","admisiones","interes","acompañarte"
    },
    "indagacion": {
        "alguna vez has considerado la posibilidad de estudiar algo mas","hay algun tema que siempre te haya llamado la atencion y que quizas te gustaria estudiar",
        "te has preguntado como seria estudiar","te gustaria estudiar en la cun","que opinas sobre la educacion continua o el aprendizaje a lo largo de la vida",
        "crees que en algun momento te gustaria ampliar tus conocimientos a traves de estudios","te ves volviendo a estudiar en el futuro",
        "que factores te harian considerar seriamente la opcion de estudiar","hay algo que te gustaria aprender o profundizar si tuvieras la oportunidad",
        "que tipo de habilidades o conocimientos te gustaria adquirir","te interesa el desarrollo personal y profesional a traves de la educacion",
        "has visto algun programa o curso que te haya parecido interesante","que piensas sobre la idea de invertir tiempo y recursos en tu formacion",
        "crees que estudiar podria abrirte nuevas puertas en el futuro","que te detendria de estudiar en este momento",
        "que necesitarias para tomar la decision de estudiar","te gustaria explorar opciones de estudio en algun momento","que tanto valoras la educacion en tu vida",
        "hay algun cambio en tu vida que podria motivarte a estudiar","que beneficios crees que podrias obtener al estudiar","estudiaste algo en el pasado",
        "como fue tu experiencia estudiando","que piensas sobre la gente que estudia actualmente","crees que la educacion es importante en general",
        "estas ocupado con otras cosas en este momento","estas ocupada con otras cosas en este momento","tienes planes a corto plazo que no incluyen estudiar",
        "estas enfocado en tu trabajo o en otras prioridades","estas enfocada en tu trabajo o en otras prioridades","sientes que necesitas estudiar algo en este momento",
        "hay algo mas que te interese hacer en lugar de estudiar","como te sientes con respecto a tu desarrollo profesional actual","crees que necesitas mas formacion para alcanzar tus metas",
        "que te parece la idea de volver a las aulas","te imaginas estudiando de nuevo alguna vez","que opinas sobre el sistema educativo actual",
        "crees que estudiar es para todos","que alternativas a la educacion formal consideras validas","te sientes realizada profesionalmente sin necesidad de mas estudios",
        "te sientes realizado profesionalmente sin necesidad de mas estudios","hay algun obstaculo importante que te impida estudiar","que necesitaria cambiar en tu vida para considerar estudiar",
        "te ves jubilando sin volver a estudiar","te sientes satisfecho con tu nivel actual de conocimientos o te gustaria seguir aprendiendo",
        "instagram con un","paga con una","indicacion","indicacion indicacion","indicacion","indicacion indicamense","indicaciones de mas","validar","confirmar","corroborar","comprobar","verificar","asegurar","certificar",
        "cuina con la","diana con el","digan con ustedes","financiaciones precisamente","mis indicaciones de","de vacaciones de","financiar con un","inducciones cuatro","inducciones y sabemos",
        "de vacaciones","de vacaciones en","brindarte con la","indicando con que","financiado no te","de vacaciones y","inducciones entonces","nacional tengo","nacional como","indicio de a","nacional en","a ligacion del",
        "nacional como","nacional pues","nacional tengo","nacional como","nacional con","ingresa in direzione","nacional manifiestas","una accion bancaria","nacional como","nacional de","nacional estos","nacional me",
        "tiendi con informacion","ciudad con daniel","viajar con aguas","nacional el","nacional nosotros","ingles con beca","nacional la","nacional y queria","naciones de","nacional estamos","nacional tengo","nacional el",
        "que necesitas","cual problema","como usas","que buscas","cuanto inviertes","por que cambiaste","que esperas","cuando decides","quien decide","que opinas","ya conocias","con que frecuencia","que presupuesto",
        "donde aplicas","que resultados","como manejas","que prioridad","has considerado","te interesa","que impacto","carrera","descubrimos","crecer","carreras","homologar"
    }, 
    "programas": {
        "ingenieria","derecho","administracion","programa","carrera","empresas","tecnica","profesional","administrativos","gestion","administrativa",
        "snies","diseño","grafico","graficos","publicaciones","sistemas","informatica","software","industrial","productivos","modas","vestuario","patronaje",
        "audiovisuales","comunicacion","social","deportiva","seguridad","salud","publicidad","mercadeo","agroindustrial","contaduria",
        "contable","financiera","comerciales","comunicativa","mercados","deportivo","territorial","territoriales"
    },
    "argumentacion": {
        "beca","descuento","financiacion","convenio","modalidad virtual","modalidad presencial","modalidad plus","plataforma","flexibilidad","titulo",
        "perfil egresado","competencias","salidas laborales","costo","valor semestre","inscripcion","metodos de pago","requisitos admision","fechas inscripcion",
        "pasos admision","icfes","homologacion","homologar","documentos homologacion","proceso homologacion","estudio homologacion","contenido programatico",
        "materias homologadas","viabilidad homologacion","solicitud de homologacion","ruta academica post-homologacion","plan homologacion","comparar modalidades",
        "comparar perfiles","comparar financiacion","analizar elegibilidad","analizar materias","analizar diferencias","reingreso","requisito reingreso",
        "proceso reingreso","formulario reingreso","verificar pendientes","elegibilidad reingreso","actualizar informacion","actualizar plan","diferencias actuales",
        "costos actuales","beneficios","requisitos","proceso","titulo previo","modalidad","presencial","virtual","distancia","convenio"
    },
    "objecion": {
        "muy caro","no tengo tiempo","lo pensare","duda","que te preocupa exactamente","entiendo tu punto","podrias contarme mas",
        "que informacion te falta","que dudas tienes","que te impide decidir","comprendo tu inquietud sobre","validamos tu preocupacion","es normal tener preguntas",
        "que necesitas para sentirte seguro/a","inversion vs gasto","retorno de inversion (roi)","valor a largo plazo","opciones de financiacion detalladas","plan de pagos",
        "becas/descuentos aplicables","comparar valor","accesibilidad","presupuesto educativo","financiacion cun","flexibilidad de horarios","modalidad virtual/distancia","estudia a tu ritmo",
        "compatible con trabajo/familia","eficiencia (ciclos prop)","optimizar tiempo","gestion del tiempo","carga academica adaptable","metas profesionales","impacto en carrera","desarrollo personal",
        "oportunidad de mercado","costo de oportunidad (no actuar)","que cambiaria con el titulo","competitividad laboral","proyeccion futura","calidad cun (saber pro)","testimonios","alianzas","trayectoria",
        "soporte del asesor","proceso paso a paso","simplificamos el tramite","plataformas intuitivas (sinu/camiticket)","acompañamiento continuo","reconocimiento men","experiencia estudiantil",
        "que otras opciones consideras","como se compara la cun","programa alternativo cun","explorar otra modalidad","iniciar mas adelante (con seguimiento)","resolver dudas puntuales","estudio gratuito",
        "ahorro significativo vs empezar de cero","costo por credito homologado","financiacion flexible","inversion inteligente","valor del tiempo ahorrado","ahorro de tiempo significativo","avanzar semestres",
        "proceso agil","validacion rapida","menos tiempo de estudio total","proceso estandarizado","requisitos claros","respuesta garantizada","te guio en cada documento","simplificacion documental","soporte cun",
        "reconocimiento de tu esfuerzo previo","construir sobre lo existente","acelerar tu meta profesional","evitar redundancia","valor del titulo completo","optimizar tu formacion","experiencia con otras ies/sena",
        "transparencia","proceso definido","casos de exito homologacion","garantia de respuesta","claridad normativa","revisar estudio de homologacion","considerar otra carrera cun","aclarar dudas especificas del proceso",
        "consultar con coordinacion academica","evaluar plan de estudios detallado","inversion para finalizar","opciones de pago disponibles","presupuesto ajustado","valor de completar titulo","facilidades de pago reintegro",
        "costo vs beneficio final","plan de estudios adaptado","carga academica flexible","organizacion del tiempo","retomar sin perder mas tiempo","actualizacion al plan vigente","soporte academico","completar ciclo",
        "logro personal/profesional","beneficios de finalizar","actualizacion necesaria","mercado laboral actual","superar obstaculos previos","renovar compromiso","soporte para la solicitud","aclaramos requisitos",
        "experiencia previa (como mejoro)","confidencialidad","compromiso institucional","facilidad tramite online","respuesta formal","evaluar transferencia interna","discutir plan de estudios","plan de accion personalizado",
        "aclarar dudas sobre materias/creditos","ciudad","campo"
    },
    "cierre": {
        "te inscribo","te llamo mañana","listo para matricularte","bienvenido","ciclos propedeuticos","3 titulos en 3 años","formacion para el futuro",
        "modalidad flexible","virtual","distancia","presencial entretenida","herramientas digitales","calidad academica","saber pro","portal de empleo",
        "servicios asistenciales","experiencia cun","bachillersitario","inscripcion facil","requisitos sencillos","plataforma sinu","camiticket",
        "admision directa","calendario academico","proceso guiado","te acompañamos","opciones de financiacion","credito educativo","icetex","sufi",
        "banco pichincha","facilidades de pago","inversion educativa","descuentos por convenio","alianzas financieras","becas","gran decision","excelente eleccion",
        "tu mejor version","unete al parche","futuro profesional","inicia ahora","oportunidad unica","empieza tu viaje","bienvenido a la cun","comunidad cunista",
        "confirmar inscripcion","enviar documentos","realizar pago","matricula","induccion","reunir papeles","formalizar admision","legalizar matricula",
        "validar conocimientos","reconocer tu titulo","ahorro tiempo y dinero","avanzar rapido","no empezar de cero","precios justos","hasta 50% homologable",
        "continuidad academica","mejorar perfil profesional","convenio sena","aprovechar estudios previos","estudio gratuito","respuesta rapida (5 dias)",
        "documentacion clara","tramite agil","homologacion en linea","te ayudo con los documentos","paso a paso","proceso simplificado","sin costo",
        "financiacion disponible","pago flexible","aplica financiacion","opciones de credito","facilidades de pago","buen camino","aprovecha tus estudios previos",
        "acelera tu carrera","felicitaciones por continuar","animate a validar","decision inteligente","continua tu formacion","preparar documentos",
        "enviar contenido tematico","enviar notas","esperar estudio","resultado homologacion","matricular asignaturas","formalizar homologacion","retomar estudios",
        "continuar tu formacion","segunda oportunidad","readmision","actualizar conocimientos","finalizar tu carrera","plan vigente","reincorporacion","culminar tu meta",
        "solicitud sencilla","formulario en linea","proceso claro","respuesta oportuna","apoyo en el tramite","fechas habilitadas",
        "requisitos minimos","tramite guiado","opciones de pago","financia tu regreso","planes de pago","credito disponible","facilidades",
        "bienvenido de nuevo","nos alegra tu regreso","retoma con exito","compromiso renovado","finaliza tu meta","estamos para apoyarte",
        "completa tu ciclo","completar solicitud","enviar carta","enviar formulario","esperar aprobacion","confirmar reintegro","realizar pago",
        "inscribir materias","formalizar regreso"
    }
}

requisitos_keywords = {
    "saludo": (1, 1/6),
    "indagacion": (1, 1/6),
    "programas": (1, 1/6),
    "argumentacion": (1, 1/6),
    "objecion": (1, 1/6),
    "cierre": (1, 1/6),
}

# ===================== Utilidades de análisis =====================
def _norm_token(s: str) -> str:
    s = s.lower()
    s = unicodedata.normalize("NFKD", s).encode("ascii", "ignore").decode("utf-8")
    return re.sub(r"\s+", " ", s).strip()

def compilar_patrones(diccionarios: dict[str, set[str]]) -> dict[str, re.Pattern]:
    patrones = {}
    for cat, claves in diccionarios.items():
        claves_norm = sorted({_norm_token(c) for c in claves if c and c.strip()})
        if not claves_norm:
            patrones[cat] = re.compile(r"^\b$")
            continue
        altern = "|".join(re.escape(c) for c in claves_norm)
        patrones[cat] = re.compile(rf"(?<!\w)({altern})(?!\w)", flags=re.IGNORECASE)
    return patrones

def normalizar_texto(texto: str) -> str:
    if not isinstance(texto, str): return ""
    t = texto.lower()
    t = unicodedata.normalize("NFKD", t).encode("ascii", "ignore").decode("utf-8")
    t = re.sub(r"[^\w\s]", " ", t)
    return re.sub(r"\s+", " ", t).strip()

def etiqueta_sentimiento_por_polarity(p: float) -> str:
    if p >= 0.1:  return "positivo"
    if p <= -0.1: return "negativo"
    return "neutro"

# ===================== Cargar cédulas desde SQL =====================
def cargar_cedulas_por_correo() -> dict:
    """
    Devuelve dict: {correo_lower: cedula_str}
    Consulta: SELECT Identificacion AS cedula, box_mail AS Correo FROM dbo.Planta_Activa
    """
    mapping = {}
    conn = None
    try:
        conn = pyodbc.connect(
            'DRIVER={ODBC Driver 17 for SQL Server};'
            f'SERVER={SQL_SERVER};'
            f'DATABASE={SQL_DATABASE};'
            f'UID={SQL_USER};'
            f'PWD={SQL_PASSWORD};'
            'Trusted_Connection=no;'
        )
        query = """
            SELECT 
                CAST(Identificacion AS VARCHAR(64)) AS cedula,
                CAST(box_mail AS VARCHAR(320))      AS Correo
            FROM dbo.Planta_Activa
            WHERE box_mail IS NOT NULL AND LTRIM(RTRIM(box_mail)) <> ''
        """
        df_map = pd.read_sql(query, conn)
        df_map["Correo"] = df_map["Correo"].str.strip().str.lower()
        df_map["cedula"] = df_map["cedula"].astype(str).str.strip()
        mapping = dict(zip(df_map["Correo"], df_map["cedula"]))
        print(f"🔗 Cargadas cédulas: {len(mapping)} correos en mapa.")
    except Exception as e:
        print(f"⚠️ No se pudo cargar cédulas desde SQL: {e}")
    finally:
        try:
            if conn is not None:
                conn.close()
        except Exception:
            pass
    return mapping

# Clasificador Naive Bayes para 'confianza'
train_data_sentiment = [
    ("Perfecto, entonces quedamos así", "positivo"),
    ("Sí, me interesa el producto", "positivo"),
    ("Muchas gracias por su ayuda", "positivo"),
    ("No me interesa en este momento", "negativo"),
    ("Estoy inconforme con la atención", "negativo"),
]
classifier_sentiment = NaiveBayesClassifier(train_data_sentiment)

# ===================== Normalizador robusto de HORA =====================
def _excel_fraction_to_hhmmss(val: float) -> str:
    # Excel guarda horas como fracción de día (0..1). Acepta 0..2 por si hay fecha+hora.
    try:
        if not (0 <= val < 2):
            return ""
        seconds = int(round((val % 1) * 86400))
        h = (seconds // 3600) % 24
        m = (seconds % 3600) // 60
        s = seconds % 60
        return f"{h:02d}:{m:02d}:{s:02d}"
    except Exception:
        return ""

def _hora_to_hhmmss(x) -> str:
    if pd.isna(x):
        return ""
    # pandas Timestamp -> datetime
    if hasattr(x, "to_pydatetime"):
        try:
            return x.to_pydatetime().strftime("%H:%M:%S")
        except Exception:
            pass
    # datetime / time
    if isinstance(x, datetime):
        return x.strftime("%H:%M:%S")
    if isinstance(x, time):
        return x.strftime("%H:%M:%S")
    # Timedelta (e.g., '0 days 17:45:00')
    if hasattr(x, "components") and hasattr(x, "total_seconds"):
        try:
            total = int(x.total_seconds())
            h = (total // 3600) % 24
            m = (total % 3600) // 60
            s = total % 60
            return f"{h:02d}:{m:02d}:{s:02d}"
        except Exception:
            pass
    xs = str(x).strip().replace(",", ".")  # coma decimal → punto
    # Caso típico SQL Server: '17:45:00.0000000' → tomar los 8 primeros HH:MM:SS
    m = re.match(r"^(\d{1,2}:\d{2}:\d{2})", xs)
    if m:
        return m.group(1)
    # Número (Excel fracción de día)
    try:
        fv = float(xs)
        hhmmss = _excel_fraction_to_hhmmss(fv)
        if hhmmss:
            return hhmmss
    except Exception:
        pass
    # Intentos controlados (sin TZ)
    for fmt in ("%H:%M:%S.%f", "%H:%M:%S", "%H:%M"):
        try:
            return pd.to_datetime(xs, format=fmt).strftime("%H:%M:%S")
        except Exception:
            continue
    # Último recurso
    try:
        ts = pd.to_datetime(xs, errors="coerce")
        return ts.strftime("%H:%M:%S") if pd.notna(ts) else ""
    except Exception:
        return ""

def _to_time7_sql(hhmmss: str) -> str:
    # Convierte 'HH:MM:SS' → 'HH:MM:SS.0000000' (compatible con SQL Server TIME(7))
    return f"{hhmmss}.0000000" if hhmmss else ""

# ===================== Pipeline (limpieza + análisis) =====================
def pipeline_df4(df4: pd.DataFrame, tipo: str = TIPO_POR_DEFECTO) -> pd.DataFrame:
    if df4 is None or df4.empty:
        raise ValueError("df4 está vacío.")

    # 1) Limpieza: elimina CUNDigital/Channel User, etc.
    df_clean = limpiar_df4(df4, dest_col="Transcripción_limpia_v2")
    s_txt = df_clean["Transcripción_limpia_v2"].fillna("").astype(str)

    # 2) Patrones por categoría
    patrones = compilar_patrones(diccionarios_keywords)

    # 3) Conteos por categoría + puntaje/efectiva
    texto_norm = s_txt.map(normalizar_texto)
    conteos_list = [{cat: len(pat.findall(t)) for cat, pat in patrones.items()} for t in texto_norm]
    df_conteos = pd.DataFrame(conteos_list).fillna(0).astype(int)

    puntajes, efectivas = [], []
    for _, row in df_conteos.iterrows():
        p = sum(peso for cat, (minimo, peso) in requisitos_keywords.items()
                if row.get(cat, 0) >= minimo)
        puntajes.append(round(p, 3))
        efectivas.append("1" if p >= 0.8 else "0")

    # 4) Sentimiento (polarity/subjectivity) + clasificación + confianza NB
    polarities, subjects, clasifs, confs, palabras, oraciones = [], [], [], [], [], []
    for txt in s_txt:
        try:
            tb  = TextBlob(txt)
            pol = float(tb.sentiment.polarity)
            sub = float(tb.sentiment.subjectivity)
            palabras.append(len(tb.words))
            oraciones.append(len(tb.sentences))
        except Exception:
            pol, sub = 0.0, 0.0
            palabras.append(0)
            oraciones.append(0)
        try:
            nb_dist = classifier_sentiment.prob_classify(txt)
            nb_pred = nb_dist.max()
            nb_conf = float(nb_dist.prob(nb_pred))
        except Exception:
            nb_conf = 0.5 + 0.5 * min(1.0, abs(pol))
        polarities.append(round(pol, 3))
        subjects.append(round(sub, 3))
        clasifs.append(etiqueta_sentimiento_por_polarity(pol))
        confs.append(round(nb_conf, 2))

    # 5) Metadatos desde df4 (incluye HORA formateada para SQL TIME(7))
    def get_first_present(df, names, default=""):
        for n in names:
            if n in df.columns:
                return df[n]
        return pd.Series([default]*len(df))

    correo_series  = get_first_present(df4, ["correo","Correo","email","Email"]).fillna("").astype(str).str.strip().str.lower()
    asesor_series  = get_first_present(df4, ["asesor","Asesor","agente","Agente","NombreAsesor"]).fillna("").astype(str)
    celular_series = get_first_present(df4, ["Phone_Number","telefono","Teléfono"]).fillna("").astype(str)
    archivo_series = get_first_present(df4, ["Id_url","Conversation_ID","id_conversation"]).fillna("").astype(str)

    if "FechaCreacion" in df4.columns:
        fecha_series = pd.to_datetime(df4["FechaCreacion"], errors="coerce").dt.date.astype("string").fillna(datetime.now().strftime("%Y-%m-%d"))
    else:
        fecha_series = pd.Series([datetime.now().strftime("%Y-%m-%d")]*len(df4), dtype="string")

    # --- Parseo robusto de HORA y formateo final para SQL Server ---
    if "hora" in df4.columns:
        hora_norm = df4["hora"].map(_hora_to_hhmmss).astype(str)  # 'HH:MM:SS'
        hora_series = hora_norm.map(_to_time7_sql)                # 'HH:MM:SS.0000000'
    else:
        hora_series = pd.Series([""]*len(df4), dtype="string")

    # 6) Cargar cédulas desde SQL y mapear por correo
    if USE_SQL_CEDULAS:
        correo_to_cedula = cargar_cedulas_por_correo()
        cedula_series = correo_series.map(lambda c: correo_to_cedula.get(c, ""))
    else:
        cedula_series = pd.Series([""]*len(df4))

    # 7) Armar salida (formato tipo "ventas")
    df_out = pd.DataFrame({
        "correo": correo_series,
        "cedula_asesor": cedula_series,
        "asesor": asesor_series,
        "asesor_corto": asesor_series,
        "fecha": fecha_series,
        **df_conteos.to_dict(orient="list"),
        "puntaje": puntajes,
        "efectiva": efectivas,
        "polarity": polarities,
        "clasificacion": clasifs,
        "confianza": confs,
        "palabras": palabras,
        "oraciones": oraciones,
        "archivo": archivo_series,
        "tamano_B": 250,
        "celular": celular_series,
        "subjectivity": subjects,
        "tipo": tipo,
        # --- HORA (SQL TIME(7)) se reordena al final abajo
        "hora": hora_series.astype(str),
    })

    columnas_salida = [
        "correo","cedula_asesor","asesor","asesor_corto","fecha",
        "saludo","indagacion","programas","argumentacion","objecion","cierre",
        "puntaje","efectiva","polarity","clasificacion","confianza",
        "palabras","oraciones","archivo","tamano_B","celular","subjectivity","tipo",
        "hora"  # <-- al final
    ]
    for c in columnas_salida:
        if c not in df_out.columns:
            df_out[c] = ""
    df_out = df_out[columnas_salida]

    # (Opcional) Si quieres DATETIME2(7) en una sola columna, descomenta:
    # fecha_hora_sql = pd.to_datetime(
    #     df_out["fecha"].astype(str) + " " + df_out["hora"].str.replace(".0000000","", regex=False),
    #     errors="coerce",
    #     format="%Y-%m-%d %H:%M:%S"
    # ).dt.strftime("%Y-%m-%d %H:%M:%S.0000000")
    # df_out.insert(len(df_out.columns), "fecha_hora", fecha_hora_sql)

    return df_out

# ===================== Ejecución directa =====================
if __name__ == "__main__":
    # 1) Cargar
    df_in = load_input(INPUT_SRC)

    # 2) Ejecutar pipeline (limpieza + análisis + cédulas)
    df_resultado = pipeline_df4(df_in, tipo=TIPO_POR_DEFECTO)

    # 3) Guardar (opcional)
    save_output(df_resultado, OUTPUT_PATH)

    # 4) Resumen
    total = len(df_resultado)
    efect = int((df_resultado["efectiva"] == "1").sum()) if "efectiva" in df_resultado.columns else 0
    porc  = (efect/total*100.0) if total else 0.0
    print(f"📊 Filas: {total} | Efectivas: {efect} ({porc:.1f}%)")
# Out:
# C:\Users\haider_bello\AppData\Local\Temp\ipykernel_17552\13960911.py:317: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_map = pd.read_sql(query, conn)
# 🔗 Cargadas cédulas: 1771 correos en mapa.
# ✅ Guardado Excel en: C:\visual\chats\resultado01-10-2025.xlsx
# 📊 Filas: 6456 | Efectivas: 4482 (69.4%)

# %%
df_limpio = limpiar_df4(df_in, dest_col="Transcripción_limpia_v2")
df_limpio.to_excel(r"C:\visual\efi 2.0\preview_limpieza.xlsx", index=False)
print("💾 Guardado preview de limpieza en C:\\visual\\efi 2.0\\preview_limpieza.xlsx")
# Out:
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/1MTp5y7mkZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Jhon  Ciro : https://fb.me/1MTp5y7mkZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Bryan Ortiz : ?Hola! Aspirante CUNISTA?
# Soy *Bryan Ortiz*, asesor de la *Corporacion Unificada Nacional CUN*?
# ???Tenemos tu registro como *interesado*, cuentame Que carrera te gustaria estudiar????
# bryan_ortiz@cun.edu.co
# https://wa.link/3s6nkw
#
# #Channel User :
# #Jhon  Ciro : https://fb.me/2kz6ta2NxA
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Que carreras y posgrado ofrecen en el Meta
# Tiene sede en pto Lopez?
# #Contact Edison Camilo : Hola!
#
# Descubre por que estudiar en la CUN es tu mejor decision!
#  Triple Titulacion: Tecnico, Tecnologo, Profesional (3 diplomas!).
#  Virtual: Estudia desde donde quieras.
#  Modelo cuatrimestral: Termina tu carrera en solo 3 anos.
# Pagos flexibles: Sin intereses ni estudio de credito.
#
# Te interesa?  Escribeme y comencemos a construir tu futuro profesional.
#
# image.png
#
# #Jhon  Ciro : Que carreras tiene
# Tiene sede en pto Lopez meta,?
# #Contact Carlos Eduardo : Voice note.mp3
# *Contamos con estos programas en modalidad virtual*-
# image.png
# Cual es el programa de tu interes?
# #Jhon  Ciro : Ok voy a revisar
# #Contact Carlos Eduardo : Cual es el programa de tu interes?
# #Jhon  Ciro : Yo soy administrador de empresas
# De la nacional
# Y quiere tener tambien el de administracion agroindustrial
# #Contact Carlos Eduardo : Perfecto
# Tienes algun convenio con la CUN?
# #Jhon  Ciro : Cuanto me vale la hologacion y si es posible hacerlo en un solo semestre
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Ayudeme averiguando eso
# #Contact Carlos Eduardo : Tu ya eres titulado?
# #Jhon  Ciro : Ahora estoy trabajando en el sector del agro y quiero complementar conocimientos
# Si, soy profesional
# #Contact Carlos Eduardo : En que ano te titulaste?
# #Jhon  Ciro : Me interesa quedar con el titulo
# #Contact Carlos Eduardo : En que ano te titulaste?
# #Jhon  Ciro : 2010
# Tengo 15 anos de experiencia profesional
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Ayudeme con buen precio para iniciar en enero
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Bueno
# Envieme info a ver si me sirve homologar
# Si me van a homologar poquitos creditos no me sirve
# #Contact Carlos Eduardo : Para homologar se requieren los siguientes documentos
# La documentacion es:
# Documento de identidad por ambos costados
# Diploma o acta de grado de bachiller
# Contenido programatico de la institucion donde estudiaste
# Certificado de notas
# Certificado de aprobacion (acta o diploma en caso de que exista o hayas culminado)
# Voice note.mp3' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/1MTp5y7mkZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Jhon  Ciro : https://fb.me/1MTp5y7mkZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Bryan Ortiz : ?Hola! Aspirante CUNISTA?
# Soy *Bryan Ortiz*, asesor de la *Corporacion Unificada Nacional CUN*?
# ???Tenemos tu registro como *interesado*, cuentame Que carrera te gustaria estudiar????
# bryan_ortiz@cun.edu.co
# https://wa.link/3s6nkw
#
# #Channel User :
# #Jhon  Ciro : https://fb.me/2kz6ta2NxA
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Que carreras y posgrado ofrecen en el Meta
# Tiene sede en pto Lopez?
# #Contact Edison Camilo : Hola!
#
# Descubre por que estudiar en la CUN es tu mejor decision!
#  Triple Titulacion: Tecnico, Tecnologo, Profesional (3 diplomas!).
#  Virtual: Estudia desde donde quieras.
#  Modelo cuatrimestral: Termina tu carrera en solo 3 anos.
# Pagos flexibles: Sin intereses ni estudio de credito.
#
# Te interesa?  Escribeme y comencemos a construir tu futuro profesional.
#
# image.png
#
# #Jhon  Ciro : Que carreras tiene
# Tiene sede en pto Lopez meta,?
# #Contact Carlos Eduardo : Voice note.mp3
# *Contamos con estos programas en modalidad virtual*-
# image.png
# Cual es el programa de tu interes?
# #Jhon  Ciro : Ok voy a revisar
# #Contact Carlos Eduardo : Cual es el programa de tu interes?
# #Jhon  Ciro : Yo soy administrador de empresas
# De la nacional
# Y quiere tener tambien el de administracion agroindustrial
# #Contact Carlos Eduardo : Perfecto
# Tienes algun convenio con la CUN?
# #Jhon  Ciro : Cuanto me vale la hologacion y si es posible hacerlo en un solo semestre
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Ayudeme averiguando eso
# #Contact Carlos Eduardo : Tu ya eres titulado?
# #Jhon  Ciro : Ahora estoy trabajando en el sector del agro y quiero complementar conocimientos
# Si, soy profesional
# #Contact Carlos Eduardo : En que ano te titulaste?
# #Jhon  Ciro : Me interesa quedar con el titulo
# #Contact Carlos Eduardo : En que ano te titulaste?
# #Jhon  Ciro : 2010
# Tengo 15 anos de experiencia profesional
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Ayudeme con buen precio para iniciar en enero
# #Contact Carlos Eduardo : Voice note.mp3
# #Jhon  Ciro : Bueno
# Envieme info a ver si me sirve homologar
# Si me van a homologar poquitos creditos no me sirve
# #Contact Carlos Eduardo : Para homologar se requieren los siguientes documentos
# La documentacion es:
# Documento de identidad por ambos costados
# Diploma o acta de grado de bachiller
# Contenido programatico de la institucion donde estudiaste
# Certificado de notas
# Certificado de aprobacion (acta o diploma en caso de que exista o hayas culminado)
# Voice note.mp3
#
# #Jhon  Ciro : Es un misterio conocer los precios de las carreras
# Gracias ya otra universidad me oferto y me sirvio el precio de ellos
# He hablado con 3 asesores de la cun y a ninguno se le ocurre responder los precios cuando le pregunto
# #Cristian Camilo : Buena tarde
# De que carrera quieres saber el valor?
# #Jhon  Ciro : Ya cuadre con otra universidad gracias
# #Cristian Camilo : Ok fue un gusto ayudarte' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/6y09IbSBe
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Fabian Lora : https://fb.me/6y09IbSBe
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Ok
# #JOSE IGNACIO : Hola ! Bienvenid@ a la CUN _?_
# Hablas con Jose Jimenez y pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #Fabian Lora : Ok
# Enfermeria
# #JOSE IGNACIO : No manejamos ese programa
# #Fabian Lora : Cuales entonces
# #JOSE IGNACIO : _?_ Carreras virtuales disponibles  CUN 2025
# _?_ Escuela de Transformacion Empresarial:
# _?_ _?_ Administracion de Empresas Agroindustriales
# _?_ _?_ Administracion de la Seguridad Social
# _?_ _??_ Administracion de Empresas
# _?_ _?_ Contaduria Publica
# _?_ Escuela de Diseno y Comunicacion:
# _?_ _?_ Direccion y Produccion de Medios Audiovisuales
# _?_ _?_ Diseno Grafico
# _?_ _?_ Comunicacion Social
# _?_ _?_ Publicidad y Mercadeo
# __ Escuela de Ingenieria:
# _?_ _?_ Ingenieria Industrial
# _?_ _?_ Ingenieria de Sistemas
# __ Escuela de Ciencias Juridicas y Gobierno:
# _?_ _?_ Administracion Publica
# _?_ Todos los programas son 100% virtuales y con registro oficial __
# Cual te interesa? _?_ Tengo una beca activa para ti _?_ Te cuento como aplicar!
# #Fabian Lora : Escuela de administracion de empresas
# #JOSE IGNACIO : ? *Administracion de Empresas*
# Forma profesionales capaces de planear, organizar, dirigir y controlar procesos en organizaciones publicas y privadas, fomentando la innovacion, el emprendimiento y la gestion eficiente de recursos.
# ? *Perfil del estudiante*
# Interes por la gestion de negocios y el liderazgo.
# Gusto por la planeacion, el trabajo en equipo y la toma de decisiones.
# Afinidad con temas financieros, comerciales y de gestion estrategica.
# ? *Lo que aprenderas*
# Fundamentos de administracion, economia y contabilidad.
# Gestion financiera, de talento humano y de operaciones.
# Mercadeo, logistica y comercio internacional.
# Innovacion, emprendimiento y transformacion digital.
# Planeacion estrategica y liderazgo empresarial.
# ? *Campo laboral*
# Podras trabajar en:
# Empresas privadas y publicas en cargos administrativos, financieros y comerciales.
# Emprendimientos propios.
# Consultoria empresarial.
# Areas de recursos humanos, planeacion, mercadeo o logistica.
# Instituciones financieras y de servicios.' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/6IxRMRxSV
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Liliana Botero : https://fb.me/6IxRMRxSV
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Mas informacion por fa
# #Brayan Sting : ? Hola! Bienvenido a la Universidad CUN
# Mi nombre es Brayan Cespedes y estare acompanandote en este proceso.
# Para brindarte la mejor asesoria, cuentame por favor:
# ? En que ciudad o municipio vives?
# ? Que edad tienes?
# ? Cuando te gustaria empezar a estudiar?
# ? Que carrera te interesa?
# ?? Prefieres estudiar en modalidad virtual o presencial?
# Estoy aqui para ayudarte en todo lo que necesites. Hablemos!
#
#
# #Liliana Botero : Vivo en Medellin
# #Karen Penagos : Hola! ?
#
# Soy *Karen Penagos*, gestora de vinculaciones para estudiantes nuevos en la *Corporacion Unificada de Educacion Superior  CUN*.
# Estoy aqui para acompanarte en todo el proceso de ingreso a tu programa academico.
# #Liliana Botero : Que carreras hay y costis porfa
# #Karen Penagos : Indicame, por favor. Cual es la carrera en especifico que estas buscando?
# #Liliana Botero : Salud
# #Karen Penagos : En que coudad estas?
# #Liliana Botero : Medellin
# #Karen Penagos : El Programa de administracion en servicios de la salud solo se maneja presencial en la ciudad de Bogota.
# Te puedo ofrecer los siguientes programas en la ciudad de Medellin
# image.png
# #Liliana Botero : Porfa
# #Karen Penagos : Mira estos dos!
# o buscas un pregrado virtual
# te ofrezco estos
# image.png
# #Liliana Botero : Administracion de empresas
# Publicidad y metcadeo
# #Karen Penagos : Voice note.mp3
# Voice note.mp3
# #Liliana Botero : Lo mas pronto
# #Karen Penagos : Inicamos el 29 de septiembre clases!
# #Liliana Botero : Y los costos porfa
# #Karen Penagos : ? Convocatoria Cun ?
# ? PROMO 2x1  Pagas tu primer semestre (virtual o presencial) al contado y el segundo semestre es GRATIS.
# ? Valor del semestre: $1.771.600
#  Con beca del 45% en tu primer semestre: paga solo $1.074.700
# ? Te obsequiamos el segundo semestre GRATIS
# ? O financia sin intereses: inscribete con solo $200.000 y difiere el resto en cuotas de $273.500
# ? No dejes pasar esta oportunidad para estudiar en la CUN!
# Tu tienes convenio con la universidad
# #Liliana Botero : Convenio como asi?
# #Karen Penagos : Tu tienes convenio con la universidad  ?
# SI-NO
# #Liliana Botero : No para nada
# #Karen Penagos : Y tienes algun estudio previo que quieras homologar?
# ? Sigues por aqui?
# Estoy listo/a si necesitas revisar algo mas.  ?
# ? Sigues por aqui?
# Estoy listo/a si necesitas revisar algo mas.  ?
#  Parece que nos desconectamos un momento ?
# Si aun necesitas ayuda, vuelve a prender tu chispa y abre un nuevo chat ?
# Estamos listos para ayudarte, Cunista! ??' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #marquezteresa565 : https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# https://www.facebook.com/share/r/1YVx5HCpaR/
# https://www.facebook.com/share/r/175AtJrtzR/
# https://www.facebook.com/share/r/1R1VZLrYai/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/16wnNZYMHJ/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/17NJzYBcRW/
# 1488782135645217.ogg
# https://www.facebook.com/share/v/1Gd9cWRB3G/
# https://www.facebook.com/share/v/19bqPZcf98/
# https://www.facebook.com/share/r/1AWgMba18c/
# 1131597218828667.ogg
# 4077897405809851.ogg
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1AyK3eN2eS/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
# #marquezteresa565 : https://www.facebook.com/share/r/1aMgL2TzCR/
# https://www.facebook.com/share/r/19KBnKJERK/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1GNSGFrKm7/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/17EiG4o6Xd/
# #alexandra  gonzalez castel : segundo gratis
# #marquezteresa565 : https://www.facebook.com/share/r/1ZHyakAhxi/
# #alexandra  gonzalez castel : Voice note.mp3
# #marquezteresa565 : https://www.facebook.com/share/v/19MsK25oG8/
# https://www.facebook.com/share/v/19MsK25oG8/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/19fu67fKXw/
# #alexandra  gonzalez castel : WhatsApp Image 2024-12-29 at 2.10.04 PM.jpeg
# #marquezteresa565 : https://www.facebook.com/share/v/1CQq2sNvrs/
# 1436894884276341.ogg
# #alexandra  gonzalez castel :
# #marquezteresa565 : https://www.facebook.com/share/r/16q9DBwAwz/
# https://www.facebook.com/share/r/1GkofapBD6/
# https://www.facebook.com/share/r/1C9XWYKeHD/
# #alexandra  gonzalez castel :' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #marquezteresa565 : https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# https://www.facebook.com/share/r/1YVx5HCpaR/
# https://www.facebook.com/share/r/175AtJrtzR/
# https://www.facebook.com/share/r/1R1VZLrYai/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/16wnNZYMHJ/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/17NJzYBcRW/
# 1488782135645217.ogg
# https://www.facebook.com/share/v/1Gd9cWRB3G/
# https://www.facebook.com/share/v/19bqPZcf98/
# https://www.facebook.com/share/r/1AWgMba18c/
# 1131597218828667.ogg
# 4077897405809851.ogg
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1AyK3eN2eS/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
# #marquezteresa565 : https://www.facebook.com/share/r/1aMgL2TzCR/
# https://www.facebook.com/share/r/19KBnKJERK/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1GNSGFrKm7/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/17EiG4o6Xd/
# #alexandra  gonzalez castel : segundo gratis
# #marquezteresa565 : https://www.facebook.com/share/r/1ZHyakAhxi/
# #alexandra  gonzalez castel : Voice note.mp3
# #marquezteresa565 : https://www.facebook.com/share/v/19MsK25oG8/
# https://www.facebook.com/share/v/19MsK25oG8/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/19fu67fKXw/
# #alexandra  gonzalez castel : WhatsApp Image 2024-12-29 at 2.10.04 PM.jpeg
# #marquezteresa565 : https://www.facebook.com/share/v/1CQq2sNvrs/
# 1436894884276341.ogg
# #alexandra  gonzalez castel :' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #marquezteresa565 : https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# https://www.facebook.com/share/r/1YVx5HCpaR/
# https://www.facebook.com/share/r/175AtJrtzR/
# https://www.facebook.com/share/r/1R1VZLrYai/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/16wnNZYMHJ/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/17NJzYBcRW/
# 1488782135645217.ogg
# https://www.facebook.com/share/v/1Gd9cWRB3G/
# https://www.facebook.com/share/v/19bqPZcf98/
# https://www.facebook.com/share/r/1AWgMba18c/
# 1131597218828667.ogg
# 4077897405809851.ogg
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1AyK3eN2eS/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
# #marquezteresa565 : https://www.facebook.com/share/r/1aMgL2TzCR/
# https://www.facebook.com/share/r/19KBnKJERK/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional. ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #marquezteresa565 : https://fb.me/55y9Xz24R
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# https://www.facebook.com/share/r/1YVx5HCpaR/
# https://www.facebook.com/share/r/175AtJrtzR/
# https://www.facebook.com/share/r/1R1VZLrYai/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/16wnNZYMHJ/
# https://www.facebook.com/share/v/1Frd9DYDWy/
# https://www.facebook.com/share/r/17NJzYBcRW/
# 1488782135645217.ogg
# https://www.facebook.com/share/v/1Gd9cWRB3G/
# https://www.facebook.com/share/v/19bqPZcf98/
# https://www.facebook.com/share/r/1AWgMba18c/
# 1131597218828667.ogg
# 4077897405809851.ogg
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1AyK3eN2eS/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
# #marquezteresa565 : https://www.facebook.com/share/r/1aMgL2TzCR/
# https://www.facebook.com/share/r/19KBnKJERK/
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #marquezteresa565 : https://www.facebook.com/share/r/1GNSGFrKm7/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/17EiG4o6Xd/
# #alexandra  gonzalez castel : segundo gratis
# #marquezteresa565 : https://www.facebook.com/share/r/1ZHyakAhxi/
# #alexandra  gonzalez castel : Voice note.mp3
# #marquezteresa565 : https://www.facebook.com/share/v/19MsK25oG8/
# https://www.facebook.com/share/v/19MsK25oG8/
# #alexandra  gonzalez castel : Hola !  Bienvenid@ a la CUN ?
# Hablas con Alexandra Gonzalez pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #marquezteresa565 : https://www.facebook.com/share/r/19fu67fKXw/
# #alexandra  gonzalez castel : WhatsApp Image 2024-12-29 at 2.10.04 PM.jpeg
# #marquezteresa565 : https://www.facebook.com/share/v/1CQq2sNvrs/
# 1436894884276341.ogg
# #alexandra  gonzalez castel :
# #marquezteresa565 : https://www.facebook.com/share/r/16q9DBwAwz/
# https://www.facebook.com/share/r/1GkofapBD6/
# https://www.facebook.com/share/r/1C9XWYKeHD/
# #alexandra  gonzalez castel :
# #marquezteresa565 : https://www.facebook.com/share/r/1Lx5rBcbL9/
# https://www.facebook.com/share/r/175odCTLsD/
# 1147662530544837.ogg
# #Contact Jeison Esteban : Buena noche, un gusto En que puedo ayudarte?' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/3x0oLNDtc
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #+573023246815 : https://fb.me/3x0oLNDtc
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Que programas manejan
# #Contact : Hola, !
# Soy Jose Ospino gerente de vinculacion asesor de la CUN. He visto que estas interesado en seguir
# avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te
# abra puertas en tu futuro.
# Antes de continuar, cuentame un poco mas sobre ti:
#  Te interesa alguna carrera o area en especial?
#  Prefieres estudiar desde casa o buscas una experiencia presencial?
# Estamos aqui para guiarte en tu crecimiento personal y profesional.
#
# #+573023246815 : Hola mi nombre es Yaidith Vergara
# Estoy interesada en una carrera
# Administracion en salud
# O salud ocupacional
# #Contact : Voice note.mp3
# #+573023246815 : Me gustaria presencial
# Pero si es virtual tambien tengo el mismo interes
# #Contact : Voice note.mp3
# #+573023246815 : Ok
# Si me interesa
# Administracion en salud
# Yo hice un tecnico y me gustaria continuar la profesional
# En la ciudad de Monteria
# #Contact : Vale, ya te doy toda la informacion
# #+573023246815 : Ok gracias
# #Contact : ? *Estudia Administracion de Servicios de Salud en la CUN  Presencial!* ?
# ? Con nuestro modelo *por ciclos propedeuticos*, obtendras *3 titulaciones en un solo plan academico*:
# ? *Tecnico Profesional en Servicios Administrativos de Salud*
# ? Semestres *1, 2 y 3*
# ? *Tecnologo en Gestion Administrativa de Empresas de Salud*
# ? Semestres *4 y 5*
# ? *Administrador de Servicios de Salud*
# ? Semestres *6, 7, 8 y 9*
# ---
# ? *Sede y jornada disponible:*
# ? *Monteria*  Carrera 4 #30-20 (Jornada Nocturna)
# ---
#  *Beneficios de estudiar en la CUN:*
#  Titulacion progresiva: Tecnico  Tecnologo  Profesional.
#  Practicas reales en el sector salud.
#  Alta empleabilidad en instituciones hospitalarias y clinicas.
#  Docentes expertos y acompanamiento academico constante.
# image.png
# Voice note.mp3
# #+573023246815 : La jornada es solo nocturna
# #Contact : Voice note.mp3
# #+573023246815 : Ah ok
# Me queda muy pesado por vivo a 40 minutos de Monteria
# Y para viajar por la noche seria un poco complicado
# #Contact : Voice note.mp3
# #+573023246815 : Ok muchas gracias cualquier cosa me estare comunicando con usted nuevamente
# #Contact : Vale, si senorita' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://www.instagram.com/p/DN9GraXAJnz/
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #"Memento Mori" : https://www.instagram.com/p/DN9GraXAJnz/
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact Jeison Esteban : Hola! ? Bienvenido al chat de la Universidad CUN.
# Mi nombre es Esteban Gamba, asesor de admisiones y becas, y estoy aqui para guiarte en todo el proceso de profesionalizacion.
# Si tienes alguna pregunta o necesitas ayuda, no dudes en escribirme. Sera un gusto acompanarte en este camino! ?
# #"Memento Mori" : Solo virtual o tambien presencial
# Que programas
# #Contact Jeison Esteban : {AA5532ED-E4FE-4135-B3EA-3856C866709F}.png
# #"Memento Mori" : Ok
# Administracion de empresas
# #Contact Jeison Esteban : Voice note.mp3
# #"Memento Mori" : 1686674315369592.ogg
# #Contact Jeison Esteban : Voice note.mp3
# #"Memento Mori" : Mede
# Medellin
# #Contact Jeison Esteban : administracion-empresas-medellin.pdf
# Voice note.mp3
# ? *Administracion de Empresas - CUN*
# #### ? *Empleabilidad*
# *Mas del 88%* de los egresados logra emplearse en areas estrategicas de organizaciones.
# #### ? *Ingreso Promedio*
# Ingreso base de cotizacion estimado: *3,2 SMMLV*
# #### ? *Cargos mas destacados*
# Gerente de operaciones
# Analista administrativo
# Director comercial
# #### ? *Sectores de contratacion*
# Comercio
# Servicios financieros
# Empresas multinacionales
# ---
# ### ? *Informacion General*
# *Modalidad*: Presencial / Virtual
# *Duracion*: 9 Semestres
# *Sedes*: Bogota, Medellin y Nacional (modalidad virtual)
# *Plan de estudios*: Tecnico, Tecnologo y Profesional
# ---
# ### ? *Por que estudiar Administracion de Empresas en la CUN?*
# *Economia, finanzas y mercadeo*: Formacion integral en areas clave para el entorno empresarial.
# *Enfoque social y sostenible*: Promueve el emprendimiento y el desarrollo de habilidades blandas.
# *Simuladores empresariales*: Fortalece la toma de decisiones estrategicas con experiencias practicas.
# *Tecnologia avanzada*: Enfrentas desafios reales usando herramientas tecnologicas actuales.
# *Oportunidades globales*: Acceso a convenios y practicas internacionales.
# *Bolsa de empleo exclusiva*: Conexion directa con oportunidades laborales disenadas para ti.
# *Liderazgo estrategico*: Preparate para dirigir cualquier organizacion o crear tu propia empresa.
# {2AE958F7-FBD2-4E50-BA84-482347042DFC}.png
# Voice note.mp3
# {77C9634E-0499-44AB-B61B-7AB1BC8E0F1A}.png
# Voice note.mp3' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/bjkD6zPsp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #+573024547211 : https://fb.me/bjkD6zPsp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact Cristian Javier : Hola buenas tardes
# cuentame en que te puedo colaborar
#
# #+573024547211 : Buenas tardes
# ?
# Hola javier como estas
# #Contact Cristian Javier : cuentame en que te puedo colaborar
# #+573024547211 : Qie carreras manejan
# #Contact Cristian Javier : Imagen de WhatsApp 2025-07-07 a las 19.08.09_7ceb0a31.jpg
# #+573024547211 : Ing industrial
# #Contact Cristian Javier : claro que si
# en este momento
# el valor del semestre queda en 947.900
# #+573024547211 : Ok se puede  diferir en cuotad
# #Contact Cristian Javier : claro que si
# pagando tu cuota inicial de 154780
#
# #Channel User :
# #+573024547211 : https://fb.me/3tyqMErzM
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Cristian Uribe : Hola apreciado aspirante, hablas con Cristian Uribe y soy tu asesor CUN encargado, me confirmas por favor  estos datos para poder brindarte una mejor asesoria
# ? Que carrera buscas?
# ? En que ciudad te encuentras?
# ? Tienes estudios previos para homologar?
# ? Tienes convenio con la CUN?
#
# #Channel User :
# #+573024547211 : https://fb.me/5XheUgCp8
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Bryan Ortiz : ??? Hola! Te saluda bryan_ortiz@cun.edu.co, asesor  de BECAS CUN ?
# ?Quieres obtener BECA exclusiva??
# ?No dejes pasar esta oportunidad!
# ?Escribeme y te ayudo con todo el proceso.
# https://wa.link/3s6nkw
# Estamos para apoyarte!
# #+573024547211 : Buenas noches
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : Industrial o alimentos
# #Bryan Ortiz : Voice note.mp3
#  Con la modalidad virtual tienes una BECA del 58%
#  Descuento ESPECIAL por pago total
#  Modulo de ingles incluido en tu matricula ?
#  Asistencia CLTiene.
#  Triple titulacion en corto tiempo (3 titulos en 3 anos)
#  Tutorias con el docente???
#  Clases sincronizadas o Asincronicas???
# #+573024547211 : Perfecto
# #Bryan Ortiz : Nombre completo:
# N de cedula:
# Telefono:
# Correo electronico:
# Direccion de domicilio y ciudad:
# Programa de Interes:
# Modalidad:
# ?Documento por ambos lados.
# ?Diploma o acta de grado
# Los tienes listos? Enviamelos por aqui y avanzamos!
# #+573024547211 : Que vale el semestre
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : Se los mandaria manana
# Que vale la inscripcion
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : Se puede pagar en mensualidades
# #Bryan Ortiz : Voice note.mp3
# image.png
# Voice note.mp3
# #+573024547211 : La clases quedan grabadas
# O debo estar siempre en ellas
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : Si mi hermano por que yo trabajo 24/7
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : El tema de parciales como serian
# #Bryan Ortiz : Voice note.mp3
# #+573024547211 : Perfecto
# #Bryan Ortiz : Voice note.mp3' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/5wSnXg6ZR
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Maribel : https://fb.me/5wSnXg6ZR
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Buenos dias indicame el proceso porfavor
# Estoy interesada en contaduria publica
# Laura no me contestas
# #Contact Laura Ximena : Buenos dias
# claro que si Maribel
# confirmame estos datos porfa
# Hola! ??
# Mi nombre es Laura Ximena Ruiz, agente de becas y admisiones para estudiantes nuevos.
# Quiero conocerte mejor para ofrecerte la orientacion que necesitas:
#  En que ciudad vives?
#  Cuantos anos tienes?
#  Tienes en mente alguna carrera o area de interes?
#  Prefieres estudiar desde casa o en modalidad presencial?
#  Tienes estudios previos que desees homologar?
#  Cuentas con algun convenio con la CUN?
#
#
# #Maribel : Hola, vengo de inscripciones y quiero encender mi futuro con la CUN. Enviame mas informacion porfa
# #Contact Laura Valentina : Un gusto!? Soy Laura Valentina Ramirez, asesora de la CUN, y estoy aqui para ayudarte a alcanzar tus metas. ?
#
# Acabo de escribirte desde mi WhatsApp corporativo(324 2668931), por alli estaremos en comunicacion y te enviare toda la informacion
#
# #Maribel : https://fb.me/56mks0Uih
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.soy una persona que voy a ser un reintegro.
# Para Contaduria Publica.
# Por favor demen una cotizacion.
# Mi numero de cedula es 28698189.
# Por favor deseo informacion
# #Jameson Rodriguez : como estas
# indicame
# -que carrea quieres estudiar
# -modalidad virtual o presencial
# -tu nombre completo
# -numero de documento
# -que nivel de estrato eres
# -de que ciudad me contestas
# -si tienes estudios previos a la carrera profesional
# -si cuentas con convenio con la universidad CUN
# #Maribel : Contaduria Publica
# Modalidad virtual
# Maribel Triana Barrero
# Cc 28698189
# Estrato3
# El Rosal Cund
# Si soy Reconocedor catastra
# #Jameson Rodriguez : PLAN-ESTUDIO-CONTADURIA-PUBLICA VIRTUAL.pdf
# Voice note.mp3
# #Maribel : Consultame porfavor yo voy para 5 semestre deseo saber los veneficios y cuanto queda el valor total
# #Jameson Rodriguez : Voice note.mp3
# #Maribel : Porfavor ya tienes toda la informacion
# #Jameson Rodriguez : Voice note.mp3
# #Maribel : Solo haga la cotizacion
# #Jameson Rodriguez : Voice note.mp3
# #Maribel : Pase porfavor una persona que sea mas preciso en la informacion
# #Jameson Rodriguez : INDICAME SI SIGUES INTERESADO EN EL PROCESO DE MATRICULA ??' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://www.instagram.com/p/DN9GprggIKs/
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Alejo Tabares  Arki Diseno y  Construccion : https://www.instagram.com/p/DN9GprggIKs/
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact Michaell Stiven : _?_ Hola! Bienvenid@ a la CUN _?_
# Mi nombre es STIVEN MURILLO y hago parte del area de Vinculacion para Nuevos Estudiantes.
# _?_ Estoy aqui para acompanarte en tu proceso de ingreso.
# Cuentame, que carrera te gustaria estudiar?
#
# #Alejo Tabares  Arki Diseno y  Construccion : Hola Michael
# #Contact Michaell Stiven : Alejo cuentame, que carrera te gustaria estudiar?
# #Alejo Tabares  Arki Diseno y  Construccion : Quiero terminar la carrera de administracion de empresas que inicie con Uds hace un tiempo
# Me puedes dar info sobre q necesito
# #Contact Michaell Stiven : ? Este canal es exclusivo para ventas. Vamos a transferir tu consulta al area de Servicio al Cliente para que puedan ayudarte. Gracias por tu comprension!
# ? Atencion Estudiantes!
# ?????? Si necesitas orientacion academica, puedes comunicarte por cualquiera de estos medios:
#
#  CamiTicket: Solicita ayuda aqui ?? https://acortar.link/xLiR4o
#  Chatbot: Escribenos al WhatsApp 3133469775 o accede desde nuestra pagina principal.
#  Redes Sociales: Encuentranos como @yosoycun
#  Correo Electronico: Escribenos a contactenos@cun.edu.co
#  CUNAPP.pro: Ingresa y sigue los pasos ?? https://cunapp.pro/
# ? Canales de atencion disponibles:
# 	1. Linea Bogota: +(60) (1) 3078180
# 	2. Linea nacional gratuita: 018000115411
# 		* Opcion 2: Rematricula
# 		* Opcion 3: Cartera
#  Estamos aqui para apoyarte en todo lo que necesites!
# _________
# Puedes comunicarte por medio de estos medios para que te ayuden con la solicitud, de igual manera escalare para que te comuniquen del area de "reintegro"
# #Alejo Tabares  Arki Diseno y  Construccion : De acuerdo
# Gracias
# #Contact Michaell Stiven : _?_ Este canal es exclusivo para ventas. Vamos a transferir tu consulta al area de Servicio al Cliente para que puedan ayudarte. Gracias por tu comprension!
#
# Bienvenid@ a este espacio donde todo prende: ideas, caminos y soluciones ?
# Soy Jairo y este es tu codigo magico: #1037785 (guardalo, lo vas a necesitar para decirnos que tan divergente fue tu experiencia).
# Estoy aqui para ayudarte con lo que necesites.
# List@ para encender esta conversacion? Como te puedo ayudar??
# ? Sigues por aqui?
# Estoy listo/a si necesitas revisar algo mas.  ?
# ? Solo para confirmar... Sigues por aqui?
# Si aun necesitas ayuda, estoy disponible ?
#  La conexion se pauso por inactividad ?
# Pero tranqui, si aun necesitas ayuda, rompe el molde e inicia un nuevo chat.
#  Estamos aqui para romper el molde contigo.?
# #Alejo Tabares  Arki Diseno y  Construccion : Hola
# #Jairo Valderrama :
# #Alejo Tabares  Arki Diseno y  Construccion : Q necesito para reingresar
# ?
# Q necesito para reingresar
# #Karen Penagos : Hola! ?
#
# Soy *Karen Penagos*, gestora de vinculaciones para estudiantes nuevos en la *Corporacion Unificada de Educacion Superior  CUN*.
# Estoy aqui para acompanarte en todo el proceso de ingreso a tu programa academico.
# Conoces ya el proceso para tu reintegro?
#  ? Revisa y completa tu reintegro aqui: https://docs.google.com/forms/d/e/1FAIpQLSfVbYMBGc_oXhTnJhx1ihTJJslMy6Je4p3ECNWT-DgOpAtDSg/viewform
# Fue un placer ayudarte! Que tengas un super dia! Sigue brillando, tu futuro te pertenece.' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/3tYAfcAJZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Luz Marina Riano : https://fb.me/3tYAfcAJZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Cristian Uribe : Hola apreciado aspirante, hablas con Cristian Uribe y soy tu asesor CUN encargado, me confirmas por favor  estos datos para poder brindarte una mejor asesoria
# ? Que carrera buscas?
# ? En que ciudad te encuentras?
# ? Tienes estudios previos para homologar?
# ? Tienes convenio con la CUN?
# #Luz Marina Riano : Que carreras virtuales ofrecen y el costo
# #Cristian Uribe : carreras virtuales.jpg
# #Luz Marina Riano : Ingenieria industrial
# Cuantos semestres y el costo por favor
# #Cristian Uribe : virtual general.mp3
# ING INDUSTRIAL.pdf
#
# #Channel User :
# #Luz Marina Riano : https://fb.me/5wSnXg6ZR
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Karen Penagos : Hola! ?
#
# Soy *Karen Penagos*, gestora de vinculaciones para estudiantes nuevos en la *Corporacion Unificada de Educacion Superior  CUN*.
# Estoy aqui para acompanarte en todo el proceso de ingreso a tu programa academico.
# Me confirmas:
# __ Carrera de interes:
# Ciudad de residencia:
# __ Tienes estudios previos:
# __ Tienes convenios con la CUN:*
# #Luz Marina Riano : Ingenieria industrial
# Ibague
# No
# No
# #Karen Penagos : *Ingenieria Industrial*
#
# esta es una de las profesiones mas solicitadas, cuenta con un amplio campo de accion en areas como *procesos, logistica, salud ocupacional, economia y finanzas;* su formacion integral desarrolla habilidades de *liderazgo, gerenciales y de emprendimiento;* y estaras en constante *innovacion y actualizacion de produccion y servicios.*
#
# *MODALIDAD-VIRTUAL*
#
#
# *DURACION 9 SEMESTRES*
# DURACION 10 SEMESTRES
# La CUN tiene beneficios unicos que transformaran tu futuro!
# **   Beca de hasta el 65%: Ahorra mientras construyes tu camino hacia el exito. Tu* educacion al alcance de tus posibilidades!
# Tres titulos en tres anos:
#
#      Inicia como Tecnico.
#      Avanza como Tecnologo.
#      Culmina como Profesional.
# #Luz Marina Riano : Y en tres anos culmina la carrera
# Cuanto es el precio del semestre y me conviene virtual
# #Karen Penagos : Si , ya que estudias cuatrimestral  ( cuatro meses)
# Haces tres cuatrimestres por ano
# 3 anos y medio excatamente terminas la carrera
# Como estamos en cierre de convocatroria este es el costo con los beneficios
# ? Recibe una beca de hasta el 65%
# ? Valor del semestre: $1.771.600
#  Con beca del 45% en tu primer semestre: paga solo $1.074.700
# ? Te obsequiamos el segundo semestre GRATIS
# ? O financia sin intereses: inscribete con solo $200.000 y difiere el resto en cuotas de $273.500
# ? No dejes pasar esta oportunidad para estudiar en la CUN!
# ? Te quedo alguna duda con lo que te comparti?
# ? Recuerda: aqui estamos para transformar tu experiencia. Escribeme sin pena ?
# #Luz Marina Riano : Estoy mirando la posibilidad que tiempo me queda para inscribirme y que requisitos piden
# #Karen Penagos : Voice note.mp3
# Voice note.mp3
# #Luz Marina Riano : Es con la cun de ibague
# #Karen Penagos : Voice note.mp3
# #Luz Marina Riano : Bueno  voy a mirar y yo le escribo muchas gracias
# #Karen Penagos : Voice note.mp3
# #Luz Marina Riano : Cuanto es el costo de la matricula?
# #Karen Penagos : No tiene costo !
# #Luz Marina Riano : Que bueno en la tarde ya le doy respuesta
# #Karen Penagos : Estare atenta , esperamos tu confirmacion a mas tardar 2pm!
#
# #Luz Marina Riano : https://fb.me/5L0rv4OOm
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #JOSE IGNACIO : Hola ! Bienvenid@ a la CUN _?_
# Hablas con Jose Jimenez y pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/8TUQOun2I
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.que ingenieria tienes
# #Dora : https://fb.me/8TUQOun2I
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.que ingenieria tienes
# #Contact Laura Ximena : Que quieres estudiar?
# #Dora : Ingenieria de sistemas o software
# #Contact Laura Ximena : claro que si!
# de forma virtual o presencial?
# #Dora : Tienes tambien curso de ingles
# Presencial donde hay sedes
# #Contact Laura Ximena : todos los semestres tienen modulo de ingles
# #Dora : Aaaa bueno
# #Contact Laura Ximena : te deje la informacion a tu wha
#
# #Channel User :
# #Dora : https://fb.me/iy23XJxtM
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #alexandra  gonzalez castel : Hola, como estas !Soy Alexandra Gonzalez , asesor de la CUN. He visto que estas interesado en seguir avanzando con tus metas y quiero ayudarte a tomar una decision que realmente te abra puertas en tu futuro.  Que carrera quieres estudiar
# WhatsApp Image 2025-08-30 at 4.42.12 PM.jpeg
# ? *Ingenieria de Sistemas  Modalidad 100% Virtual*
# ? *Institucion:* Corporacion Unificada Nacional de Educacion Superior  CUN
# ? *Modalidad:* Virtual
#  *Duracion:* 3 anos (9 semestres  3 por ano)
# ? Formacion por *ciclos propedeuticos*:
# 1 Tecnico Profesional en Soporte de Sistemas
# 2 Tecnologo en Desarrollo de Software
# 3 Profesional Universitario en Ingenieria de Sistemas
# ? Obtienes un *titulo por cada ciclo*, facilitando el acceso progresivo al mercado laboral.
# ---
#
# ### ? *Que aprenderas?*
# Seras un ingeniero capaz de disenar, desarrollar, implementar y gestionar sistemas tecnologicos, con habilidades de programacion, analisis de datos, redes y soluciones digitales.
# ? *Areas clave del plan de estudios:*
# Programacion en Python, Java, C#, entre otros lenguajes
# Desarrollo de aplicaciones web, moviles y de escritorio
# Bases de datos, administracion de informacion y seguridad informatica
# Redes, infraestructura y ciberseguridad
# Inteligencia artificial, big data y machine learning
# Gestion de proyectos TI con metodologias agiles
# Emprendimiento tecnologico e innovacion digital
# ? Campo laboral: empresas tecnologicas, multinacionales, emprendimientos, bancos, aseguradoras, sector publico, consultoria en TI, desarrollo de software y proyectos de transformacion digital.
# ---
#
# ### ? *Metodologia Virtual  CUN*
#  Plataforma academica disponible 24/7
#  6 materias por semestre (en 2 bloques de 3 materias cada uno)
#  Clases en vivo entre lunes y viernes de *6:00 p.m. a 9:30 p.m.*, 3 a 4 veces por semana
#  Todas las clases quedan *grabadas*
#  *No hay asistencia obligatoria*
#  *Tutoria academica personalizada semanal*
# ? Ideal para personas que trabajan, emprenden o necesitan estudiar con total flexibilidad.
# ---
#
# ###  *Aplica modelo 3-3-5?*
#  Si. Puedes *terminar la carrera en 3 anos* cursando *3 semestres por ano*
#  La solicitud para aplicar al modelo debe hacerse *a mitad del primer semestre*.
# Tu solicitud sera atendida por nuestra area especializada, quien te ayudara en tu proceso academico por medio de llamada o por medio de WhatsApp  3227995805. ?' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/cASi7Cmwp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Empresa de Articulos  : https://fb.me/cASi7Cmwp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Lilia Vasquez :
# *Hola!* hablas con *Johanna Vasquez.* ? Asesora de *vinculaciones* de la *CUN*.
#
#
# *Para brindarte todos tus beneficios activos, por favor confirmame lo siguiente:*
#         En que ciudad vives?
#         Cuantos anos tienes?
#         Tienes estudios tecnicos o tecnologos que desees homologar?, *(indicar nombre de la titulacion, fecha de graduacion y nombre de la institucion en la que te graduaste)*
#         Cuentas con algun convenio con la CUN?
#         Cual es tu carrera de interes?
#         Deseas estudiar en modalidad presencial o virtual?
#
# *Quedo atento a tu respuesta para continuar!*
# #Empresa de Articulos  : Buen dia estoy en dosquebrads
# Tengo bachillerato
# #Lilia Vasquez :  Cual es tu carrera de interes?
# #Empresa de Articulos  : Administracion o ingenieria en sistemas
# #Lilia Vasquez : EMPRESAS.png
# ADMINISTRACION DE EMPRESAS-VIRTUAL.pdf
# SISTEMAS.png
# INGENIERIA SISTEMAS -VIRTUAL.pdf
# *?PROMOCION 1*
#
# Matriculate *Hoy* en modalidad virtual y recibe: *Beca institucional del 65% y bono extra del 35%*
# ?Valor semestre: $ 3.480.600 *Solo por HOY $ 1.229.590*
# *?Inscribete con: $ 200.383*
# ?El restante lo diferimos a 4 cuotas mensuales de *$ 273.584*
# *?PROMOCION 2*
#
# *?*Valor del semestre con *beca institucional 65% + bono del 45%*
# *?Pago de contado $1.074.730*
# *?Realiza el pago total de tu semestre y el siguiente semestre te queda totalmente gratis*
# #Empresa de Articulos  : Muchas gracias. Esta muy bueno pero me sale altico el precio no me alcanza
# #Lilia Vasquez : Y pagar a cuotas?
# *Hola*
# Solo te escribo para recordarte que seguimos aqui para resolver cualquier duda.
# ...
# #VARIEDADES GILMITA : Gracias
# No hay disponible psicologia
# Gracias
# #Luz Carreno :' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/cASi7Cmwp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #m : https://fb.me/cASi7Cmwp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact Wilson Esteban : ? Hola! Te saluda Wilson Duarte, Gestor de Becas y Admisiones de la Universidad CUN ?
# ? Nos estamos preparando para empezar clases e inducciones, por eso te invitamos a asegurar tu cupo desde ya.
# ? Tu semestre virtual con beca hasta el 60% de descuento
# ? Aprovecha que hoy es dia de pago para realizar tu abono inicial y no perder este beneficio.
#  Si deseas avanzar, respondeme SIMPLEMENTE con dos letras un SI o un NO y de inmediato te envio la informacion del programa que desees o cerramos el contacto.
# ? Escribeme ya y asegura tu ingreso para este nuevo periodo academico!
#
# carerras presenciales por ciudad.jpeg
# #m : Mas informacion
# #Contact Wilson Esteban : Que carrera de las que te envie en las fotos te interesa, para ampliar la informacion.
# #m : Administracion de los
# #Contact Wilson Esteban : servicios de la salud presencial en bogota ?
# #m : Y virtual..
# #Contact Wilson Esteban : carreras VIRTUALES.jpeg
# #m : Que se necesita para obtener una beca en comunicacion social
# #Contact Wilson Esteban : ? Te apasiona la comunicacion, el periodismo y las redes sociales?
# Conviertelo en tu carrera profesional con Comunicacion Social en la CUN! ??
#  Estudia desde cualquier lugar (virtual o presencial) y *obten 3 titulaciones en solo 3 anos* gracias al modelo por ciclos propedeuticos en modalidad virtual:
# ? Ciclo de formacion por etapas:
# 1 Ano 1: Tecnico Profesional en Produccion de Contenidos Informativos
# 2 Ano 2: Tecnologo en Gestion Comunicativa en las Organizaciones
# 3 Ano 3: Profesional en Comunicacion Social
# ? Materias clave: Periodismo digital, gestion de la comunicacion organizacional.
# ? Ingreso promedio: Desde 3,1 SMMLV
# ? Alta empleabilidad: cerca del 80% de los egresados trabajan en medios o agencias.
# ? Convenios con grandes medios como RCN, Citytv y Canal Capital.
#
#  Programa CL: incluye seguro de asistencias completamente GRATIS con:
# Servicio medico en casa
# Salud oral
# Ambulancia
# Reparacion de electrodomesticos
# Atencion a mascotas y mas!
# ? Conviertete en el comunicador que transforma la sociedad!
# Quieres mas informacion sobre becas o el proceso de inscripcion?
# Voice note.mp3
# Para solicitar la beca, por favor brindame estos datos:
# ? Cedula :
# ? Fecha de expedicion y de nacimiento:
# ? Lugar de nacimiento y de expedicion del documento:
# ? Nombre:
# ? Correo electronico:
# ? Edad:
# ? Ciudad y direccion de domicilio:
# ? Tienes convenio con nosotros?:
# Documento de identidad en PDF o foto legible por ambos lados para la orden de pago.
# ? Quedo atento a tu respuesta
# ? Solo para confirmar... Sigues por aqui?
# Si aun necesitas ayuda, estoy disponible ?
# Sigues ahi? Si no recibimos respuesta en 1 minuto, cerraremos esta conversacion. Puedes escribirnos cuando lo necesites ?.
#
# https://wa.link/1y3w5v
# Wilson_duartet@cun.edu.co' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/3tYAfcAJZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Mi Familia    Mi Mundo : https://fb.me/3tYAfcAJZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Hola luz
# #Luz Carreno : Hola, aspirante CUNista! ?
# Soy Luz Dary Carreno, gestora de vinculaciones de la Universidad CUN ?.
# ed905fdf-278c-4478-aa15-93b928cefd20.jpeg
# #Mi Familia    Mi Mundo : Reynaldo arrieta oquendo
# 48 anos
# Cartagena
# Cc 3800471
# raos.77@hotmail.com
# Ing industrial
# #Luz Carreno : Perfecto
# Captura de pantalla 2025-02-06 083317.png
# Captura de pantalla 2025-02-06 083137 - copia - copia.png
# ingenieria-industrial-digital.pdf
# CL tiene.jpeg
# Captura de pantalla 2025-07-01 183653.png
# Captura de pantalla 2025-07-07 091859.png
# ? Estos son los costos que tenemos disponibles hoy en la Universidad CUN, disenados para que puedas pagar mucho mas economico aprovechando el beneficio exclusivo que tenemos para personas realmente interesadas en estudiar y salir adelante ?
# Contamos con valores muy accesibles, diferentes opciones de pago, y varios beneficios adicionales que facilitan tu proceso educativo y te permiten avanzar sin obstaculos.
# Estoy aqui para ayudarte en todo lo que necesites y resolver cualquier duda que tengas.
# Aprovecha esta oportunidad!
# Holaaa buenas tardes
# #Mi Familia    Mi Mundo : Biena noches
# #Luz Carreno : Holaa buenos dias
# #Mi Familia    Mi Mundo : Muy buenos dias
# #Luz Carreno : Como estas senor Reynaldo, continuamos con el proceso?
# *Senor Reynaldo, muy buenos dias. Espero que se encuentre muy bien.*
# Con respecto a lo que me comentas sobre tus dudas, entiendo completamente que puedas sentir algo de desconfianza; es valido y natural. Sin embargo, quiero aclararte que te estas comunicando directamente con la linea oficial de la universidad. El contacto se dio por medio de la pagina oficial, y es desde ahi donde hemos estado en comunicacion contigo.
# Si deseas mayor tranquilidad, puedes llamar directamente a la linea institucional de la universidad para corroborar toda la informacion que se te ha brindado. Esa es una opcion completamente valida y queda a tu criterio.
# En cuanto al proceso de inscripcion, este se realiza unicamente desde la sede principal en Bogota, ya que manejamos la modalidad virtual para todos los tramites, incluyendo los registros presenciales o virtuales. En Sincelejo no se realiza directamente ningun proceso de inscripcion, por lo tanto, si decides ir hasta alla, lo mas probable es que te remitan nuevamente a nosotros.
# Somos los unicos autorizados para gestionar los procesos de inscripcion, asi como para ofrecer los beneficios y descuentos vigentes. Por eso, te reitero la invitacion a que, si deseas continuar con el proceso, verifiques la informacion por los canales oficiales y asi puedas sentirte completamente seguro.
# Quedo muy atenta si deseas avanzar o si tienes alguna otra duda.
# Holaa muy buenas tardes
# #Mi Familia    Mi Mundo : Hola
# Ya cuadre una visita a la oficina aqui en cartagena
# Si tienen sede aca
# #Luz Carreno : Como te fue senor Reynaldo, ya validaste la informacion?
# Cuando vas a ir?
# #Mi Familia    Mi Mundo : Manana
# #Luz Carreno : Claro que si, senor Reynaldo, usted puede acercarse si asi lo desea. Sin embargo, es importante recordarle que, como le mencione anteriormente, en esa sede no lo van a poder atender, ya que usted no se encuentra registrado ni tiene historial con esa oficina.
# Ese punto de atencion esta destinado unicamente para personas antiguas que, en algun momento, tuvimos manejo o relacion directa con dicha sede. Por lo tanto, alli no se realiza ningun proceso nuevo para quienes no tienen ese antecedente.
# No obstante, si desea ir personalmente a corroborar la informacion, puede hacerlo. Incluso puede mostrar este chat como evidencia de que ya tuvo contacto con un asesor. Sin embargo, es muy probable que igual no puedan brindarle el servicio alli, y en ese caso, debera volver a comunicarse por este medio.
# De igual manera, estare muy atenta a su caso y le informare a mis jefes directos que usted tiene previsto acercarse a la sede de Cartagena.
# #Mi Familia    Mi Mundo : Ok
# Est manana me dijo que no habia sede aqui en cartagena
# Que la mas cerca era la de sincelejo
# Entonces esperemos a ver
# #Luz Carreno : Hola buenos dias
# Voice note.mp3
# Hola buenos dias
#
# #Mi Familia    Mi Mundo : https://fb.me/2M4QqCYdu
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact Ana Maria : ?Hola! Aspirante CUNISTA?
#
# Soy *Anamaria Rayo*, gestor de Becas y Vinculaciones de la Corporacion Unificada Nacional CUN?
# ???Tenemos tu registro como interesado, cuentame Que carrera te gustaria estudiar????
#
# ana_rayo@cun.edu.co
# https://wa.link/xr7gjg
#
# #Mi Familia    Mi Mundo : https://fb.me/3tyqMErzM
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Brayan Sting : ? Hola! Bienvenido a la *Universidad CUN*
# Mi nombre es *Brayan Cespedes* y estare acompanandote en este proceso.
# Para brindarte la mejor asesoria, cuentame por favor:
# ? En que ciudad o municipio vives?
# ? Que edad tienes?
# ? Cuando te gustaria empezar a estudiar?
# ? Que carrera te interesa?
# ?? Prefieres estudiar en modalidad _virtual_ o _presencial_?
# Estoy aqui para ayudarte en todo lo que necesites. Hablemos!
# Sigues en linea?}
#
# #Channel User :
# #Mi Familia    Mi Mundo : https://fb.me/5l5NMTRQG
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Contact : Hola!
#
# Descubre por que estudiar en la CUN es tu mejor decision!
#  Triple Titulacion: Tecnico, Tecnologo, Profesional (3 diplomas!).
#  Virtual: Estudia desde donde quieras.
#  Modelo cuatrimestral: Termina tu carrera en solo 3 anos.
# Pagos flexibles: Sin intereses ni estudio de credito.
#
# Te interesa?  Escribeme y comencemos a construir tu futuro profesional. ' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/bjkD6zPsp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Recreando Momentos : https://fb.me/bjkD6zPsp
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #Ricardo Alvarez : Somos #CUN CORPORACION UNIFICADA NACIONAL DE EDUCACION SUPERIOR https://cun.edu.co/
# Estamos aqui para ayudarte en cada paso. ? Soy *Ricardo Alvarez* encargado de procesos de admision.??????
# PROGRAMAS VIRTUALES.jpeg
# #Recreando Momentos : Comunicacion social
# #Ricardo Alvarez : PLAN-ESTUDIO-COMUNICACION-SOCIAL-VIRTUAL.pdf
# Que dudas tienes, para poder ayudarte y brindarte los costos y beneficios de estudiar con nosotros?
# image.png
# https://youtu.be/ykRynwzHNBE
# Te relaciono calendario de convocatoria actual.
# *CONVOCATORIA 25V04 VIRTUAL*
# *Periodo Academico* lunes, agosto 04, 2025 hasta domingo, noviembre 23, 2025
# *Jornada de Induccion* lunes, julio 28, 2025 hasta sabado, agosto 02, 2025
# *Primer Bloque* lunes, agosto 04, 2025 hasta domingo, septiembre 28, 2025
# *Segundo Bloque* lunes, septiembre 29, 2025 hasta domingo, noviembre 23, 2025
# #Recreando Momentos : Me pueden llamar para brindarme mejor la.informacion
# #Ricardo Alvarez : a que hora deseas la llamada
# #Recreando Momentos : 1754087325480874.ogg
# #Ricardo Alvarez : me recuerdas tu nombre
# te estoy llamando, pero no contestaste
# al numero que marcamos *3244057249*
# Continuas en linea, recuerda que el chat se cierra por inactividad.
#
#
# #Channel User :
# #Recreando Momentos : https://fb.me/1MTp5y7mkZ
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Informacion
# Sobre carreras y costos
# #Jose Humberto : Buenos dias
# Modalidad Virtual contamos con estas carreras???????:
#
# 1. Administracion de Empresas
# 2. Administracion de Empresas Agroindustriales
# 3. Administracion Publica
# 4. Contaduria Publica
# 5. Ingenieria de Sistemas
# 6. Ingenieria Industrial
# 7. Direccion y Produccion de medios Audiovisuales
# 8. Publicidad y Mercadeo
# 9. Comunicacion Social
# 10. Diseno grafico
# 11. Administracion de la seguridad social
# Que pregrado te interesa?
# #Recreando Momentos : Comunicacion social
# Que costo tiene y como seria el proceso
# O administracion publica
# #Jose Humberto : comunicacion-social-virtual-presencial.pdf
# image.png
# #Recreando Momentos : Como serian los costos
# #Jose Humberto : administracion_publica_2024 (2)_compressed (1).pdf
# image.png
# Voice note.mp3
# Voice note.mp3
#
# #Channel User :
# #Recreando Momentos : https://fb.me/iy23XJxtM
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# Ok
# #Contact Cristian Javier : Hola. Mi nombre es Cristian Garcia, agente de becas y admisiones para estudiantes nuevos.
# Quiero conocerte mejor para ofrecerte la orientacion que necesitas:
#  En que ciudad vives?
#  Cuantos anos tienes?
#  Para cuando tienes proyectado estudiar?
#  Tienes en mente alguna carrera o area de interes?
#  Prefieres estudiar desde casa o en modalidad presencial?
#  Tienes estudios previos que desees homologar?
#  Cuentas con algun convenio con la CUN?' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# c:\visual\.venv\Lib\site-packages\xlsxwriter\worksheet.py:1249: UserWarning: Ignoring URL 'https://fb.me/63ml2AhE6
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #miguel : https://fb.me/63ml2AhE6
#
# Hola! ? Me interesa estudiar un pregrado virtual en la CUN.
# #JOSE IGNACIO : Hola ! Bienvenid@ a la CUN _?_
# Hablas con Jose Jimenez y pertenezco al area de vinculaciones para estudiantes nuevos
# Que carrera deseas estudiar?
# #miguel : Cuales tienes
# #JOSE IGNACIO : ? Carreras virtuales disponibles  CUN 2025
# ? Escuela de Transformacion Empresarial:
# ? ? Administracion de Empresas Agroindustriales
# ? ? Administracion de la Seguridad Social
# ? ?? Administracion de Empresas
# ? ? Contaduria Publica
# ? Escuela de Diseno y Comunicacion:
# ? ? Direccion y Produccion de Medios Audiovisuales
# ? ? Diseno Grafico
# ? ? Comunicacion Social
# ? ? Publicidad y Mercadeo
#  Escuela de Ingenieria:
# ? ? Ingenieria Industrial
# ? ? Ingenieria de Sistemas
#  Escuela de Ciencias Juridicas y Gobierno:
# ? ? Administracion Publica
# ? Todos los programas son 100% virtuales y con registro oficial
# Cual te interesa? ? Tengo una beca activa para ti ? Te cuento como aplicar!
# #miguel : Las ingenieria
# #JOSE IGNACIO : Cual ingenieria te llama la atencion?
# #miguel : Ambas
# #JOSE IGNACIO : ? Estudia Ingenieria de Sistemas en la CUN y alcanza tu maximo potencial en el mundo tecnologico!
# ? Empleabilidad: +96% de egresados con empleo
# ? Ingreso promedio: 3,8 SMMLV
# ? Triple titulacion:
# 1 Tecnico Profesional en Soporte de Sistemas e Informatica (Semestres 1, 2, 3 y 4)
# 2 Tecnologo en Desarrollo de Software (Semestres 5, 6 y 7)
# 3 Ingeniero de Sistemas (Semestres 8, 9 y 10)
# ? Modalidad: Presencial o Virtual  Estudia desde cualquier ciudad ??
# ? Aprenderas:
# ? Desarrollo de software y programacion avanzada
# ? Gestion de redes, hardware y bases de datos
# ? Analisis de datos e inteligencia de negocios
# ? Ciberseguridad y gestion de sistemas
# ? Innovacion tecnologica y soluciones digitales
#  Ventajas CUN:
#  Experiencia internacional: Estudia en Mexico o Chile
#  Conexion con lideres de la industria: Capacitaciones con IBM, HUAWEI y EVERIS
#  Bolsa de empleo CUN Work para vinculacion laboral desde cualquier parte del pais
#  Certificaciones internacionales en CISCO, ORACLE y TESTOUT
# ? Inicio de clases: 29 de septiembre
# ? Beca institucional: Ultimos cupos disponibles!
# ? Estudia Ingenieria Industrial en la CUN y alcanza tu maximo potencial!
# ? Empleabilidad: +92% de egresados con empleo
# ? Ingreso promedio: 3,2 SMMLV
# ? Triple titulacion:
# 1 Tecnico Profesional en Registro de Procesos Productivos
# 2 Tecnologo en Gestion de Procesos Productivos y Administrativos
# 3 Ingeniero Industrial
# ? Modalidad: 100% virtual  Estudia desde cualquier ciudad ??
# ? Aprenderas:
# ? Optimizacion de procesos y metodos para mayor competitividad
# ? Logistica, inventarios y cadena de suministro
# ? Gestion de calidad, sostenibilidad y seguridad laboral
# ? Finanzas, costos, presupuestos y mercadeo
# ? Programacion, analisis de datos y diagramacion de procesos
#  Ventajas CUN:
#  Ciclos propedeuticos: trabaja antes de graduarte
#  Formacion en liderazgo, emprendimiento e innovacion
#  Alta demanda laboral en manufactura, logistica, consultoria y finanzas
# ? Inicio de clases: 29 de septiembre
# ? Beca institucional: Ultimos cupos disponibles!
# #miguel : Valor
# #JOSE IGNACIO : image.png
# #miguel : El valor total es de ?
# #JOSE IGNACIO : Voice note.mp3
# Miguel, sigues en linea?' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLs.
#   warn(
# 💾 Guardado preview de limpieza en C:\visual\efi 2.0\preview_limpieza.xlsx

# %%
import nltk
nltk.download('punkt')       # tokenizador clásico
nltk.download('punkt_tab')   # requerido por NLTK recientes
nltk.download('stopwords')   # (opcional) útil para otros procesos
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\haider_bello\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\haider_bello\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\haider_bello\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True
