# %%
import importlib.metadata as m
import ctranslate2

print("faster-whisper:", m.version("faster-whisper"))
print("ctranslate2:", m.version("ctranslate2"))
print("torch.cuda.is_available():", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU torch:", torch.cuda.get_device_name(0))
print("ctranslate2 cuda devices:", ctranslate2.get_cuda_device_count())
# Out:
# faster-whisper: 1.2.1
# ctranslate2: 4.6.2
# torch.cuda.is_available(): False
# ctranslate2 cuda devices: 1

# %% [markdown]
# ## resumen mejorado

# %%
# -*- coding: utf-8 -*-
"""
Notas:
- Si el modelo te corta el JSON, sube OLLAMA_OPTIONS["num_predict"] (p.ej. 2200).
- Si el modelo soporta más contexto, sube num_ctx a 8192 para menos “pérdida” en clases largas.
"""

import os
import json
import re
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any, Tuple
import inspect
import requests
import boto3
from boto3.s3.transfer import TransferConfig
import ctranslate2
import torch
from faster_whisper import WhisperModel


# ================== CONFIGURACIÓN S3 ==================

S3_BUCKET = "cun-transcribe-five9"
S3_PREFIX_VIDEOS = "Videos_clase_Profesores/video_12_04_25a/"  # termina en '/'

# Opcional: subir también los JSON a S3
UPLOAD_JSON_TO_S3 = False
S3_PREFIX_JSON = "Videos_clase_Profesores/video_12_04_25a/resumenes/"  # carpeta para los JSON

# Cliente S3
s3 = boto3.client("s3")

# Descargas S3 más rápidas (ajusta max_concurrency según tu red)
S3_DOWNLOAD_CONFIG = TransferConfig(
    multipart_threshold=64 * 1024 * 1024,  # 64MB
    multipart_chunksize=16 * 1024 * 1024,  # 16MB
    max_concurrency=10,
    use_threads=True,
)

VIDEO_EXTS = {".mp4", ".mkv", ".avi", ".mov", ".wmv"}


# ================== CONFIGURACIÓN LOCAL ==================

LOCAL_VIDEO_DIR = Path(r"C:\videos_clases_s3")
LOCAL_VIDEO_DIR.mkdir(parents=True, exist_ok=True)

TRANSCRIPTS_DIR = Path(r"C:\transcripciones_clases_s3\video_12_04_25a")
TRANSCRIPTS_DIR.mkdir(parents=True, exist_ok=True)

JSON_DIR = Path(r"C:\resumenes_clases_json_s3\12_04_25a")
JSON_DIR.mkdir(parents=True, exist_ok=True)

# Si quieres probar con pocos videos:
LIMIT_VIDEOS: Optional[int] = None  # ej: 2  | None = todos



# ================== WHISPER (TRANSCRIPCIÓN) ==================

# OJO: faster-whisper usa CTranslate2. Torch puede estar en CPU y aun así Whisper ir en GPU.
CT2_CUDA_DEVICES = ctranslate2.get_cuda_device_count()
DEVICE = "cuda" if CT2_CUDA_DEVICES > 0 else "cpu"

MODEL_NAME = "medium"
COMPUTE_TYPE = "float16" if DEVICE == "cuda" else "int8"
LANG = "es"

WHISPER_BATCH_SIZE = 16 if DEVICE == "cuda" else 1

print(f"[WHISPER] CT2_CUDA_DEVICES={CT2_CUDA_DEVICES} | DEVICE={DEVICE} | COMPUTE_TYPE={COMPUTE_TYPE} | BATCH={WHISPER_BATCH_SIZE}")



# ================== OBJETIVOS DE ESTUDIO (CONTROL DE LARGO) ==================

RESUMEN_GENERAL_PALABRAS = (150, 220)
RESUMEN_ESTUDIO_PALABRAS = (600, 900)

PUNTOS_CLAVE_CANTIDAD = (10, 16)
TEMAS_PRINCIPALES_CANTIDAD = (6, 10)
GLOSARIO_CANTIDAD = (10, 18)
PREGUNTAS_REPASO_CANTIDAD = (6, 10)


# ================== OLLAMA (RESUMEN) ==================

OLLAMA_URL = os.environ.get("OLLAMA_URL", "http://localhost:11434")
OLLAMA_MODEL = os.environ.get("OLLAMA_MODEL", "qwen2.5:7b-instruct")

OLLAMA_OPTIONS = {
    "temperature": 0.2,
    "top_p": 0.9,
    "num_ctx": 4096,     # si tu modelo lo soporta, prueba 8192
    "num_predict": 2000  # sube a 2000-2400 si el JSON se corta
}

# timeouts: (connect_timeout, read_timeout)
OLLAMA_TIMEOUT: Tuple[int, int] = (10, 1800)  # 10s connect, 30min read
OLLAMA_RETRIES = 3

# Tamaño máximo por chunk (si hay demasiados chunks, el resumen se vuelve muy lento)
MAX_CHARS_PER_CHUNK = 20000
MAX_CHUNKS_HARD_LIMIT = 8  # si supera, hacemos chunks más grandes automáticamente


# ================== LOG ==================

def log(msg: str):
    ts = time.strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] {msg}")


# ================== UTILIDADES ==================

def save_text(path: Path, text: str):
    tmp = path.with_suffix(path.suffix + ".tmp")
    tmp.write_text(text, encoding="utf-8")
    tmp.replace(path)

def read_text(path: Path) -> str:
    return path.read_text(encoding="utf-8", errors="ignore")

def safe_json_loads(s: str) -> Optional[dict]:
    try:
        return json.loads(s)
    except Exception:
        return None

def extract_json_fallback(s: str) -> Optional[dict]:
    """
    Fallback por si Ollama devuelve texto alrededor del JSON.
    """
    s = (s or "").strip()
    if not s:
        return None

    # Caso directo
    j = safe_json_loads(s)
    if isinstance(j, dict):
        return j

    # Buscar primer bloque {...}
    start, end = s.find("{"), s.rfind("}")
    if start != -1 and end != -1 and end > start:
        j = safe_json_loads(s[start:end + 1])
        if isinstance(j, dict):
            return j

    m = re.search(r"\{.*\}", s, re.DOTALL)
    if m:
        j = safe_json_loads(m.group(0))
        if isinstance(j, dict):
            return j

    return None

def _ensure_list(x) -> list:
    if x is None:
        return []
    if isinstance(x, list):
        return x
    return [x]

def _ensure_str(x) -> str:
    return "" if x is None else str(x)

def normalize_summary_json(j: Dict[str, Any], video_name: str) -> Dict[str, Any]:
    """
    Asegura que el JSON final tenga TODAS las llaves esperadas y tipos consistentes.
    """
    if not isinstance(j, dict):
        j = {}

    out = {
        "video": video_name,
        "resumen_general": _ensure_str(j.get("resumen_general", "")),
        "resumen_estudio": _ensure_str(j.get("resumen_estudio", "")),
        "puntos_clave": _ensure_list(j.get("puntos_clave", [])),
        "temas_principales": _ensure_list(j.get("temas_principales", [])),
        "conceptos_importantes": _ensure_list(j.get("conceptos_importantes", [])),
        "glosario": _ensure_list(j.get("glosario", [])),
        "preguntas_repaso": _ensure_list(j.get("preguntas_repaso", [])),
        "tareas_o_recomendaciones": _ensure_list(j.get("tareas_o_recomendaciones", [])),
    }

    # Normaliza glosario y preguntas al formato esperado si vienen como strings
    glos = []
    for it in out["glosario"]:
        if isinstance(it, dict):
            glos.append({"termino": _ensure_str(it.get("termino", "")), "definicion": _ensure_str(it.get("definicion", ""))})
        else:
            s = _ensure_str(it).strip()
            if s:
                glos.append({"termino": s, "definicion": ""})
    out["glosario"] = glos

    preg = []
    for it in out["preguntas_repaso"]:
        if isinstance(it, dict):
            preg.append({"pregunta": _ensure_str(it.get("pregunta", "")), "respuesta_corta": _ensure_str(it.get("respuesta_corta", ""))})
        else:
            s = _ensure_str(it).strip()
            if s:
                preg.append({"pregunta": s, "respuesta_corta": ""})
    out["preguntas_repaso"] = preg

    return out


# ================== S3: LISTAR / DESCARGAR / SUBIR ==================

def list_s3_videos(bucket: str, prefix: str) -> List[str]:
    keys: List[str] = []
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):
            key = obj["Key"]
            if Path(key).suffix.lower() in VIDEO_EXTS:
                keys.append(key)
    return keys

def download_s3_video(bucket: str, key: str, local_dir: Path) -> Path:
    local_path = local_dir / Path(key).name
    if local_path.exists():
        log(f"➡️ Video ya descargado: {local_path.name}")
        return local_path

    local_dir.mkdir(parents=True, exist_ok=True)
    log(f"⬇️ Descargando: s3://{bucket}/{key}")
    s3.download_file(bucket, key, str(local_path), Config=S3_DOWNLOAD_CONFIG)
    log(f"✅ Descargado: {local_path}")
    return local_path

def upload_json_to_s3(local_json: Path, bucket: str, prefix: str):
    key = prefix.rstrip("/") + "/" + local_json.name
    log(f"⬆️ Subiendo JSON a S3: s3://{bucket}/{key}")
    s3.upload_file(str(local_json), bucket, key)
    log("✅ JSON subido a S3")


# ================== WHISPER ==================

def load_whisper_model():
    log(f"🔊 Cargando Whisper '{MODEL_NAME}' en {DEVICE} (compute_type={COMPUTE_TYPE}) ...")

    kwargs = dict(
        device=DEVICE,
        compute_type=COMPUTE_TYPE,
    )

    # algunas versiones soportan device_index
    import inspect
    sig = inspect.signature(WhisperModel)
    if "device_index" in sig.parameters and DEVICE == "cuda":
        kwargs["device_index"] = 0

    model = WhisperModel(MODEL_NAME, **kwargs)

    log("✅ Whisper cargado.")
    return model


def transcribe_video(model: WhisperModel, video_path: Path, out_txt: Path, force: bool = False) -> Path:
    if out_txt.exists() and not force:
        log(f"➡️ TXT ya existe: {out_txt.name}")
        return out_txt

    log(f"🎧 Transcribiendo: {video_path.name} (batch_size={WHISPER_BATCH_SIZE}) ...")
    t0 = time.time()

    # kwargs base (compatibles)
    kwargs = dict(
        language=LANG,
        vad_filter=True,
        vad_parameters=dict(min_silence_duration_ms=400),
        beam_size=1,
        best_of=1,
        temperature=0.0,
        condition_on_previous_text=False,
    )

    # Estos flags no existen en algunas versiones viejas, así que los agregamos SOLO si están
    sig = inspect.signature(model.transcribe)
    params = sig.parameters

    if "without_timestamps" in params:
        kwargs["without_timestamps"] = True
    if "word_timestamps" in params:
        kwargs["word_timestamps"] = False
    if "batch_size" in params:
        kwargs["batch_size"] = WHISPER_BATCH_SIZE

    segments, info = model.transcribe(str(video_path), **kwargs)

    text = "".join(seg.text for seg in segments).strip()
    save_text(out_txt, text)

    dt = time.time() - t0
    log(f"✅ TXT guardado: {out_txt.name} ({len(text)} chars) | {dt/60:.1f} min")
    return out_txt


# ================== OLLAMA ==================

def call_ollama_json(prompt: str) -> Dict[str, Any]:
    """
    Llama a Ollama forzando salida JSON y con retries.
    """
    payload = {
        "model": OLLAMA_MODEL,
        "prompt": prompt,
        "stream": False,
        "format": "json",
        "keep_alive": "60m",
        "options": OLLAMA_OPTIONS,
    }

    last_err = None
    for attempt in range(1, OLLAMA_RETRIES + 1):
        try:
            resp = requests.post(f"{OLLAMA_URL}/api/generate", json=payload, timeout=OLLAMA_TIMEOUT)
            resp.raise_for_status()
            data = resp.json()
            raw = (data.get("response") or "").strip()

            j = safe_json_loads(raw)
            if isinstance(j, dict):
                return j

            j2 = extract_json_fallback(raw)
            if isinstance(j2, dict):
                return j2

            raise ValueError("Ollama devolvió respuesta sin JSON válido.")

        except Exception as e:
            last_err = e
            wait = min(20, 2 ** attempt) + random.random()
            log(f"⚠️ Ollama error (intento {attempt}/{OLLAMA_RETRIES}): {e} | reintento en {wait:.1f}s")
            time.sleep(wait)

    raise RuntimeError(f"Falló Ollama tras {OLLAMA_RETRIES} intentos. Último error: {last_err}")


# ================== PROMPTS ==================

def build_summary_prompt_full(transcript: str, video_name: str) -> str:
    gmin, gmax = RESUMEN_GENERAL_PALABRAS
    emin, emax = RESUMEN_ESTUDIO_PALABRAS
    pmin, pmax = PUNTOS_CLAVE_CANTIDAD
    tmin, tmax = TEMAS_PRINCIPALES_CANTIDAD
    glmin, glmax = GLOSARIO_CANTIDAD
    qmin, qmax = PREGUNTAS_REPASO_CANTIDAD

    return f"""
Eres un asistente experto en educación que transforma transcripciones de clases en apuntes para estudiar.

Vas a recibir la transcripción casi completa de una CLASE en español.
Debes devolver SOLO un objeto JSON válido con esta estructura (sin texto adicional):

{{
  "video": "{video_name}",
  "resumen_general": "Resumen rápido de {gmin}-{gmax} palabras (1 párrafo).",
  "resumen_estudio": "Apuntes para estudiar de {emin}-{emax} palabras, con subtítulos y viñetas cuando aplique. Incluye: (1) qué se explicó, (2) pasos/procesos, (3) ejemplos si aparecen, (4) conclusiones.",
  "puntos_clave": ["{pmin}-{pmax} bullets, cada bullet 10-18 palabras aprox."],
  "temas_principales": ["{tmin}-{tmax} temas (frases cortas)."],
  "conceptos_importantes": ["lista de conceptos importantes (solo nombres, sin definición larga)."],
  "glosario": [{{"termino":"...","definicion":"definición corta 1-2 líneas"}}],  // entre {glmin}-{glmax} items
  "preguntas_repaso": [{{"pregunta":"...","respuesta_corta":"..."}}],            // entre {qmin}-{qmax} items
  "tareas_o_recomendaciones": ["si el profesor dejó tareas o sugerencias; si no, []"]
}}

Reglas:
- El JSON debe ser válido (comillas dobles, sin comentarios).
- Escribe en español claro.
- NO agregues nada fuera del JSON.
- Respeta los rangos de palabras y cantidades indicados.

Transcripción:
--------------------------
{transcript}
--------------------------
""".strip()

def build_chunk_summary_prompt(chunk_text: str, idx: int, total: int, video_name: str) -> str:
    # Para fragmentos, pedimos un resumen “denso” (ayuda al consolidado)
    return f"""
Estás ayudando a resumir una clase larga de video.

Este es el fragmento {idx}/{total} de la transcripción de la clase "{video_name}".

Devuelve SOLO un objeto JSON válido con esta estructura:

{{
  "fragmento": {idx},
  "resumen_fragmento": "120-180 palabras. Explica qué se enseñó y cómo, con el mayor detalle útil.",
  "puntos_clave_fragmento": ["6-10 bullets con ideas accionables / definiciones / pasos"]
}}

Reglas:
- JSON válido (comillas dobles).
- Sin texto adicional fuera del JSON.

Transcripción del fragmento:
----------------------------
{chunk_text}
----------------------------
""".strip()


# ================== CHUNKING ==================

def chunk_text(text: str, max_chars: int = MAX_CHARS_PER_CHUNK) -> List[str]:
    text = text.strip()
    if len(text) <= max_chars:
        return [text]

    chunks: List[str] = []
    start = 0
    n = len(text)

    while start < n:
        end = min(n, start + max_chars)
        cut = text.rfind(".", start, end)
        if cut == -1 or cut <= start + int(max_chars * 0.6):
            cut = end
        else:
            cut = cut + 1
        chunk = text[start:cut].strip()
        if chunk:
            chunks.append(chunk)
        start = cut

    return chunks


# ================== RESUMEN GLOBAL ==================

def summarize_transcript_with_ollama(transcript: str, video_name: str) -> Dict[str, Any]:
    transcript = (transcript or "").strip()
    if not transcript:
        return normalize_summary_json({}, video_name)

    # Primer chunking
    chunks = chunk_text(transcript, max_chars=MAX_CHARS_PER_CHUNK)

    # Si quedan demasiados chunks, hacemos chunks más grandes para no demorar horas
    if len(chunks) > MAX_CHUNKS_HARD_LIMIT:
        log(f"⚠️ Muchos fragmentos ({len(chunks)}). Aumentando tamaño de chunk para acelerar...")
        bigger = min(20000, MAX_CHARS_PER_CHUNK * 3)
        chunks = chunk_text(transcript, max_chars=bigger)

    log(f"🧩 {video_name}: {len(chunks)} fragmentos")

    # Si hay un solo fragmento: resumen directo
    if len(chunks) == 1:
        t0 = time.time()
        prompt = build_summary_prompt_full(chunks[0], video_name)
        j = call_ollama_json(prompt)
        j = normalize_summary_json(j, video_name)
        log(f"✅ Resumen (1 paso) listo | {(time.time()-t0)/60:.1f} min")
        return j

    # Resumen por fragmentos
    fragment_summaries: List[Dict[str, Any]] = []
    for i, chunk in enumerate(chunks, start=1):
        log(f"   ↳ Ollama fragmento {i}/{len(chunks)} ...")
        prompt = build_chunk_summary_prompt(chunk, i, len(chunks), video_name)
        frag = call_ollama_json(prompt)
        if not isinstance(frag, dict):
            frag = {"fragmento": i, "resumen_fragmento": "", "puntos_clave_fragmento": []}
        fragment_summaries.append(frag)

    # Consolidación final
    resumenes_txt = []
    for frag in fragment_summaries:
        num = frag.get("fragmento")
        r = frag.get("resumen_fragmento", "")
        pts = frag.get("puntos_clave_fragmento", [])
        resumenes_txt.append(f"Fragmento {num}:\nResumen: {r}\nPuntos clave: {pts}\n")

    texto_para_resumen_final = "\n\n".join(resumenes_txt)

    gmin, gmax = RESUMEN_GENERAL_PALABRAS
    emin, emax = RESUMEN_ESTUDIO_PALABRAS
    pmin, pmax = PUNTOS_CLAVE_CANTIDAD
    tmin, tmax = TEMAS_PRINCIPALES_CANTIDAD
    glmin, glmax = GLOSARIO_CANTIDAD
    qmin, qmax = PREGUNTAS_REPASO_CANTIDAD

    prompt_final = f"""
Eres un asistente experto en educación que genera apuntes para estudiar a partir de resúmenes parciales.

Se te dará una serie de resúmenes por fragmento de la clase "{video_name}".
Con esa información, genera un único JSON con esta estructura:

{{
  "video": "{video_name}",
  "resumen_general": "Resumen rápido de {gmin}-{gmax} palabras (1 párrafo).",
  "resumen_estudio": "Apuntes para estudiar de {emin}-{emax} palabras, con subtítulos y viñetas cuando aplique. Incluye: (1) qué se explicó, (2) pasos/procesos, (3) ejemplos si aparecen, (4) conclusiones.",
  "puntos_clave": ["{pmin}-{pmax} bullets, cada bullet 10-18 palabras aprox."],
  "temas_principales": ["{tmin}-{tmax} temas (frases cortas)."],
  "conceptos_importantes": ["lista de conceptos importantes (solo nombres)."],
  "glosario": [{{"termino":"...","definicion":"definición corta 1-2 líneas"}}],  // {glmin}-{glmax}
  "preguntas_repaso": [{{"pregunta":"...","respuesta_corta":"..."}}],            // {qmin}-{qmax}
  "tareas_o_recomendaciones": ["tareas o recomendaciones; si no hay, []"]
}}

Reglas:
- Usa SOLO la información de los resúmenes de fragmento.
- El JSON debe ser válido.
- Todo en español.
- Respeta los rangos de palabras y cantidades indicados.
- NO agregues texto fuera del JSON.

Resúmenes de fragmentos:
------------------------
{texto_para_resumen_final}
------------------------
""".strip()

    log("🧠 Consolidando resumen final ...")
    t0 = time.time()
    j_final = call_ollama_json(prompt_final)
    j_final = normalize_summary_json(j_final, video_name)
    log(f"✅ Resumen final listo | {(time.time()-t0)/60:.1f} min")
    return j_final


# ================== PIPELINE PRINCIPAL ==================

def procesar_videos_desde_s3():
    model = load_whisper_model()

    keys = list_s3_videos(S3_BUCKET, S3_PREFIX_VIDEOS)
    if not keys:
        log(f"⚠️ No se encontraron videos en s3://{S3_BUCKET}/{S3_PREFIX_VIDEOS}")
        return

    if LIMIT_VIDEOS is not None:
        keys = keys[:LIMIT_VIDEOS]

    log(f"🎬 Videos encontrados: {len(keys)}")

    for idx, key in enumerate(keys, start=1):
        video_name = Path(key).name
        stem = Path(key).stem

        txt_path = TRANSCRIPTS_DIR / f"{stem}.txt"
        json_out = JSON_DIR / f"{stem}_resumen.json"

        log("=" * 90)
        log(f"[{idx}/{len(keys)}] ▶️ {video_name}")

        # ✅ Si ya existe el JSON final, saltar todo
        if json_out.exists():
            log(f"➡️ Ya existe JSON: {json_out.name} | Salto.")
            continue

        video_path: Optional[Path] = None
        try:
            # ✅ Si ya existe TXT, no descargamos video
            if txt_path.exists():
                log(f"➡️ TXT ya existe: {txt_path.name} | No descargo video.")
            else:
                # Descargar + transcribir
                t0 = time.time()
                video_path = download_s3_video(S3_BUCKET, key, LOCAL_VIDEO_DIR)
                log(f"⏱️ Descarga: {(time.time()-t0)/60:.1f} min")

                transcribe_video(model, video_path, txt_path, force=False)

            transcript = read_text(txt_path)

            # Resumir
            t0 = time.time()
            resumen = summarize_transcript_with_ollama(transcript, video_name)
            log(f"⏱️ Resumen total: {(time.time()-t0)/60:.1f} min")

            # Guardar JSON (atómico)
            tmp = json_out.with_suffix(".json.tmp")
            with tmp.open("w", encoding="utf-8") as f:
                json.dump(resumen, f, ensure_ascii=False, indent=2)
            tmp.replace(json_out)
            log(f"💾 JSON guardado: {json_out}")

            if UPLOAD_JSON_TO_S3:
                upload_json_to_s3(json_out, S3_BUCKET, S3_PREFIX_JSON)

        except Exception as e:
            log(f"❌ Error procesando {video_name}: {e}")

        finally:
            # 🧹 Borra video SOLO si se descargó en este ciclo
            if video_path and video_path.exists():
                try:
                    video_path.unlink()
                    log(f"🧹 Video local eliminado: {video_path.name}")
                except Exception as e:
                    log(f"⚠️ No se pudo borrar {video_path}: {e}")


if __name__ == "__main__":
    procesar_videos_desde_s3()
# Out:
# [WHISPER] CT2_CUDA_DEVICES=1 | DEVICE=cuda | COMPUTE_TYPE=float16 | BATCH=16
# [2025-12-30 09:10:14] 🔊 Cargando Whisper 'medium' en cuda (compute_type=float16) ...
# [2025-12-30 09:10:17] ✅ Whisper cargado.
# [2025-12-30 09:10:19] 🎬 Videos encontrados: 139
# [2025-12-30 09:10:19] ==========================================================================================
# [2025-12-30 09:10:19] [1/139] ▶️ FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4
# [2025-12-30 09:10:19] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4
# [2025-12-30 09:11:02] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4
# [2025-12-30 09:11:02] ⏱️ Descarga: 0.7 min
# [2025-12-30 09:11:02] 🎧 Transcribiendo: FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:15:37] ✅ TXT guardado: FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.txt (54319 chars) | 4.6 min
# [2025-12-30 09:15:37] 🧩 FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 09:15:37]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 09:15:43] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.3s
# [2025-12-30 09:16:50] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 4.6s
# [2025-12-30 09:18:02] ⚠️ Ollama error (intento 3/3): Ollama devolvió respuesta sin JSON válido. | reintento en 8.6s
# [2025-12-30 09:18:10] ❌ Error procesando FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4: Falló Ollama tras 3 intentos. Último error: Ollama devolvió respuesta sin JSON válido.
# [2025-12-30 09:18:10] 🧹 Video local eliminado: FUNDAMENTOS DE CONTABILIDAD TALLER OPCION 1 - 2025_12_03 17_53 GMT-05_00 - Recording.mp4
# [2025-12-30 09:18:10] ==========================================================================================
# [2025-12-30 09:18:10] [2/139] ▶️ FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4
# [2025-12-30 09:18:10] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4
# [2025-12-30 09:19:40] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4
# [2025-12-30 09:19:40] ⏱️ Descarga: 1.5 min
# [2025-12-30 09:19:40] 🎧 Transcribiendo: FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:26:12] ✅ TXT guardado: FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.txt (53452 chars) | 6.5 min
# [2025-12-30 09:26:12] 🧩 FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 09:26:12]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 09:26:35]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 09:26:47]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 09:27:00] 🧠 Consolidando resumen final ...
# [2025-12-30 09:27:47] ✅ Resumen final listo | 0.8 min
# [2025-12-30 09:27:47] ⏱️ Resumen total: 1.6 min
# [2025-12-30 09:27:47] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording_resumen.json
# [2025-12-30 09:27:48] 🧹 Video local eliminado: FUNDAMENTOS DE FOTOGRAFÍA 55505-55503-556665 - 2025_12_03 17_52 GMT-05_00 - Recording.mp4
# [2025-12-30 09:27:48] ==========================================================================================
# [2025-12-30 09:27:48] [3/139] ▶️ FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 09:27:48] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 09:28:33] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 09:28:33] ⏱️ Descarga: 0.8 min
# [2025-12-30 09:28:33] 🎧 Transcribiendo: FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:33:04] ✅ TXT guardado: FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.txt (46776 chars) | 4.5 min
# [2025-12-30 09:33:04] 🧩 FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 09:33:04]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 09:33:12]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 09:33:28]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 09:33:41] 🧠 Consolidando resumen final ...
# [2025-12-30 09:34:22] ✅ Resumen final listo | 0.7 min
# [2025-12-30 09:34:22] ⏱️ Resumen total: 1.3 min
# [2025-12-30 09:34:22] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording_resumen.json
# [2025-12-30 09:34:23] 🧹 Video local eliminado: FUNDAMENTOS DE MERCADEO - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 09:34:23] ==========================================================================================
# [2025-12-30 09:34:23] [4/139] ▶️ FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 09:34:23] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 09:35:24] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 09:35:24] ⏱️ Descarga: 1.0 min
# [2025-12-30 09:35:24] 🎧 Transcribiendo: FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:41:17] ✅ TXT guardado: FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.txt (45880 chars) | 5.9 min
# [2025-12-30 09:41:17] 🧩 FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 09:41:17]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 09:41:38]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 09:41:54]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 09:42:07] 🧠 Consolidando resumen final ...
# [2025-12-30 09:42:44] ✅ Resumen final listo | 0.6 min
# [2025-12-30 09:42:44] ⏱️ Resumen total: 1.5 min
# [2025-12-30 09:42:44] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording_resumen.json
# [2025-12-30 09:42:44] 🧹 Video local eliminado: FUNDAMENTOS DE MERCADEO - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 09:42:44] ==========================================================================================
# [2025-12-30 09:42:44] [5/139] ▶️ FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4
# [2025-12-30 09:42:44] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4
# [2025-12-30 09:43:51] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4
# [2025-12-30 09:43:51] ⏱️ Descarga: 1.1 min
# [2025-12-30 09:43:51] 🎧 Transcribiendo: FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:52:15] ✅ TXT guardado: FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.txt (71820 chars) | 8.4 min
# [2025-12-30 09:52:15] 🧩 FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 09:52:15]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 09:52:30]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 09:52:42]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 09:52:57]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 09:53:08] 🧠 Consolidando resumen final ...
# [2025-12-30 09:53:41] ✅ Resumen final listo | 0.6 min
# [2025-12-30 09:53:41] ⏱️ Resumen total: 1.4 min
# [2025-12-30 09:53:41] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording_resumen.json
# [2025-12-30 09:53:42] 🧹 Video local eliminado: FUNDAMENTOS DE MONTAJE AUDIOVISUAL - 2025_12_03 17_54 GMT-05_00 - Recording.mp4
# [2025-12-30 09:53:42] ==========================================================================================
# [2025-12-30 09:53:42] [6/139] ▶️ FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4
# [2025-12-30 09:53:42] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4
# [2025-12-30 09:54:16] ✅ Descargado: C:\videos_clases_s3\FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4
# [2025-12-30 09:54:16] ⏱️ Descarga: 0.6 min
# [2025-12-30 09:54:16] 🎧 Transcribiendo: FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 09:59:15] ✅ TXT guardado: FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.txt (44004 chars) | 5.0 min
# [2025-12-30 09:59:15] 🧩 FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 09:59:15]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 09:59:33]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 09:59:49]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 10:00:01] 🧠 Consolidando resumen final ...
# [2025-12-30 10:00:42] ✅ Resumen final listo | 0.7 min
# [2025-12-30 10:00:42] ⏱️ Resumen total: 1.5 min
# [2025-12-30 10:00:42] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:00:42] 🧹 Video local eliminado: FUNDAMENTOS DEL (SGSS I)_55541_55543 SEGUNDO BLOQUE_25V05 - 2025_12_03 18_06 GMT-05_00 - Recording.mp4
# [2025-12-30 10:00:42] ==========================================================================================
# [2025-12-30 10:00:42] [7/139] ▶️ Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:00:42] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:01:06] ✅ Descargado: C:\videos_clases_s3\Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:01:06] ⏱️ Descarga: 0.4 min
# [2025-12-30 10:01:06] 🎧 Transcribiendo: Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:04:00] ✅ TXT guardado: Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.txt (29364 chars) | 2.9 min
# [2025-12-30 10:04:00] 🧩 Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 10:04:00]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 10:04:14]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 10:04:29] 🧠 Consolidando resumen final ...
# [2025-12-30 10:05:21] ✅ Resumen final listo | 0.9 min
# [2025-12-30 10:05:21] ⏱️ Resumen total: 1.4 min
# [2025-12-30 10:05:21] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:05:21] 🧹 Video local eliminado: Fundamentos de Economía - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:05:21] ==========================================================================================
# [2025-12-30 10:05:21] [8/139] ▶️ Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4
# [2025-12-30 10:05:21] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4
# [2025-12-30 10:06:03] ✅ Descargado: C:\videos_clases_s3\Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4
# [2025-12-30 10:06:03] ⏱️ Descarga: 0.7 min
# [2025-12-30 10:06:03] 🎧 Transcribiendo: Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:08:22] ✅ TXT guardado: Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.txt (36758 chars) | 2.3 min
# [2025-12-30 10:08:22] 🧩 Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 10:08:22]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 10:08:35]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 10:08:49] 🧠 Consolidando resumen final ...
# [2025-12-30 10:09:18] ✅ Resumen final listo | 0.5 min
# [2025-12-30 10:09:18] ⏱️ Resumen total: 0.9 min
# [2025-12-30 10:09:18] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:09:18] 🧹 Video local eliminado: Fundamentos de Mantenimiento (25V06) _ IDD24 - 2025_12_03 18_48 GMT-05_00 - Recording.mp4
# [2025-12-30 10:09:18] ==========================================================================================
# [2025-12-30 10:09:18] [9/139] ▶️ Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:09:18] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:10:07] ✅ Descargado: C:\videos_clases_s3\Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:10:07] ⏱️ Descarga: 0.8 min
# [2025-12-30 10:10:07] 🎧 Transcribiendo: Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:16:38] ✅ TXT guardado: Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.txt (57532 chars) | 6.5 min
# [2025-12-30 10:16:38] 🧩 Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 10:16:38]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 10:16:48]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 10:17:03]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 10:17:17]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 10:17:23] 🧠 Consolidando resumen final ...
# [2025-12-30 10:17:46] ✅ Resumen final listo | 0.4 min
# [2025-12-30 10:17:46] ⏱️ Resumen total: 1.1 min
# [2025-12-30 10:17:46] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:17:46] 🧹 Video local eliminado: Fundamentos de Publicidad - 2025_12_03 19_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:17:46] ==========================================================================================
# [2025-12-30 10:17:46] [10/139] ▶️ Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:17:46] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:18:34] ✅ Descargado: C:\videos_clases_s3\Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:18:34] ⏱️ Descarga: 0.8 min
# [2025-12-30 10:18:34] 🎧 Transcribiendo: Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:20:13] ✅ TXT guardado: Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.txt (37516 chars) | 1.6 min
# [2025-12-30 10:20:13] 🧩 Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 10:20:13]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 10:20:32]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 10:20:38] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.9s
# [2025-12-30 10:20:49]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 10:20:57] 🧠 Consolidando resumen final ...
# [2025-12-30 10:21:20] ✅ Resumen final listo | 0.4 min
# [2025-12-30 10:21:20] ⏱️ Resumen total: 1.1 min
# [2025-12-30 10:21:20] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:21:20] 🧹 Video local eliminado: Fundamentos de economía - 2025_12_03 17_47 GMT-05_00 - Recording.mp4
# [2025-12-30 10:21:20] ==========================================================================================
# [2025-12-30 10:21:20] [11/139] ▶️ Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4
# [2025-12-30 10:21:20] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4
# [2025-12-30 10:21:50] ✅ Descargado: C:\videos_clases_s3\Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4
# [2025-12-30 10:21:50] ⏱️ Descarga: 0.5 min
# [2025-12-30 10:21:50] 🎧 Transcribiendo: Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:23:26] ✅ TXT guardado: Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.txt (35472 chars) | 1.6 min
# [2025-12-30 10:23:26] 🧩 Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 10:23:26]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 10:24:30] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.4s
# [2025-12-30 10:25:36] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 4.0s
# [2025-12-30 10:26:44] ⚠️ Ollama error (intento 3/3): Ollama devolvió respuesta sin JSON válido. | reintento en 8.7s
# [2025-12-30 10:26:53] ❌ Error procesando Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4: Falló Ollama tras 3 intentos. Último error: Ollama devolvió respuesta sin JSON válido.
# [2025-12-30 10:26:53] 🧹 Video local eliminado: Fundamentos de economía - 2025_12_03 19_30 GMT-05_00 - Recording.mp4
# [2025-12-30 10:26:53] ==========================================================================================
# [2025-12-30 10:26:53] [12/139] ▶️ GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 10:26:53] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 10:27:54] ✅ Descargado: C:\videos_clases_s3\GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 10:27:54] ⏱️ Descarga: 1.0 min
# [2025-12-30 10:27:54] 🎧 Transcribiendo: GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:31:14] ✅ TXT guardado: GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.txt (66624 chars) | 3.3 min
# [2025-12-30 10:31:14] 🧩 GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 10:31:14]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 10:31:22]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 10:31:33]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 10:31:39] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.9s
# [2025-12-30 10:32:00]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 10:32:16] 🧠 Consolidando resumen final ...
# [2025-12-30 10:32:59] ✅ Resumen final listo | 0.7 min
# [2025-12-30 10:32:59] ⏱️ Resumen total: 1.8 min
# [2025-12-30 10:32:59] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:32:59] 🧹 Video local eliminado: GERENCIA DE MARCA_ 55504 (25V05) - 55526 (25P05) - 56654 (25P06) - 56668 (25V06) - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 10:32:59] ==========================================================================================
# [2025-12-30 10:32:59] [13/139] ▶️ GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4
# [2025-12-30 10:32:59] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4
# [2025-12-30 10:33:48] ✅ Descargado: C:\videos_clases_s3\GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4
# [2025-12-30 10:33:48] ⏱️ Descarga: 0.8 min
# [2025-12-30 10:33:48] 🎧 Transcribiendo: GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:36:58] ✅ TXT guardado: GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.txt (60755 chars) | 3.2 min
# [2025-12-30 10:36:58] 🧩 GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 10:36:58]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 10:37:11]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 10:37:30]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 10:37:46]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 10:37:56] 🧠 Consolidando resumen final ...
# [2025-12-30 10:38:25] ✅ Resumen final listo | 0.5 min
# [2025-12-30 10:38:25] ⏱️ Resumen total: 1.4 min
# [2025-12-30 10:38:25] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:38:25] 🧹 Video local eliminado: GERENCIA DE MERCADEO - 25V05_25V06_25P05_25P06-55557-55573-55575-55685-56605-56697 - 2025_12_03 17_59 GMT-05_00 - Recording.mp4
# [2025-12-30 10:38:25] ==========================================================================================
# [2025-12-30 10:38:25] [14/139] ▶️ GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 10:38:25] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 10:39:09] ✅ Descargado: C:\videos_clases_s3\GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 10:39:09] ⏱️ Descarga: 0.7 min
# [2025-12-30 10:39:09] 🎧 Transcribiendo: GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:41:26] ✅ TXT guardado: GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.txt (52676 chars) | 2.3 min
# [2025-12-30 10:41:26] 🧩 GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 10:41:26]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 10:41:43]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 10:42:00]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 10:42:14] 🧠 Consolidando resumen final ...
# [2025-12-30 10:42:54] ✅ Resumen final listo | 0.7 min
# [2025-12-30 10:42:54] ⏱️ Resumen total: 1.5 min
# [2025-12-30 10:42:54] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:42:54] 🧹 Video local eliminado: GERENCIA DEL CAPITAL INTELECTUAL PERIODO 25V05 - ID 55587 - 55570 - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 10:42:54] ==========================================================================================
# [2025-12-30 10:42:54] [15/139] ▶️ GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4
# [2025-12-30 10:42:54] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4
# [2025-12-30 10:43:22] ✅ Descargado: C:\videos_clases_s3\GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4
# [2025-12-30 10:43:22] ⏱️ Descarga: 0.5 min
# [2025-12-30 10:43:22] 🎧 Transcribiendo: GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:45:02] ✅ TXT guardado: GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.txt (37826 chars) | 1.7 min
# [2025-12-30 10:45:02] 🧩 GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 10:45:02]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 10:45:13]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 10:45:24]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 10:45:30] 🧠 Consolidando resumen final ...
# [2025-12-30 10:45:39] ✅ Resumen final listo | 0.2 min
# [2025-12-30 10:45:39] ⏱️ Resumen total: 0.6 min
# [2025-12-30 10:45:39] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:45:39] 🧹 Video local eliminado: GERENCIA PÚBLICA INTEGRALDIC2025DOCMARCELAPEÑA - 2025_12_03 18_04 GMT-05_00 - Recording.mp4
# [2025-12-30 10:45:39] ==========================================================================================
# [2025-12-30 10:45:39] [16/139] ▶️ GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4
# [2025-12-30 10:45:39] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4
# [2025-12-30 10:46:20] ✅ Descargado: C:\videos_clases_s3\GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4
# [2025-12-30 10:46:20] ⏱️ Descarga: 0.7 min
# [2025-12-30 10:46:20] 🎧 Transcribiendo: GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:49:33] ✅ TXT guardado: GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.txt (57113 chars) | 3.2 min
# [2025-12-30 10:49:33] 🧩 GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 10:49:33]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 10:49:39] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.5s
# [2025-12-30 10:49:47] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 4.8s
# [2025-12-30 10:49:59] ⚠️ Ollama error (intento 3/3): Ollama devolvió respuesta sin JSON válido. | reintento en 8.6s
# [2025-12-30 10:50:08] ❌ Error procesando GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4: Falló Ollama tras 3 intentos. Último error: Ollama devolvió respuesta sin JSON válido.
# [2025-12-30 10:50:08] 🧹 Video local eliminado: GESTION LOGISTICA - 55550_25V05 - 56691_25V06 - 56693_25V06 - 2025_12_03 18_00 GMT-05_00 - Recording.mp4
# [2025-12-30 10:50:08] ==========================================================================================
# [2025-12-30 10:50:08] [17/139] ▶️ GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:50:08] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:50:52] ✅ Descargado: C:\videos_clases_s3\GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:50:52] ⏱️ Descarga: 0.7 min
# [2025-12-30 10:50:52] 🎧 Transcribiendo: GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:53:38] ✅ TXT guardado: GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.txt (50319 chars) | 2.8 min
# [2025-12-30 10:53:38] 🧩 GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 10:53:38]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 10:53:57]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 10:54:15]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 10:54:29] 🧠 Consolidando resumen final ...
# [2025-12-30 10:55:20] ✅ Resumen final listo | 0.9 min
# [2025-12-30 10:55:20] ⏱️ Resumen total: 1.7 min
# [2025-12-30 10:55:20] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording_resumen.json
# [2025-12-30 10:55:20] 🧹 Video local eliminado: GESTION LOGISTICA_55552_55586_56683 - 2025_12_03 20_01 GMT-05_00 - Recording.mp4
# [2025-12-30 10:55:20] ==========================================================================================
# [2025-12-30 10:55:20] [18/139] ▶️ GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4
# [2025-12-30 10:55:20] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4
# [2025-12-30 10:56:22] ✅ Descargado: C:\videos_clases_s3\GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4
# [2025-12-30 10:56:22] ⏱️ Descarga: 1.0 min
# [2025-12-30 10:56:22] 🎧 Transcribiendo: GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 10:59:42] ✅ TXT guardado: GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.txt (62170 chars) | 3.3 min
# [2025-12-30 10:59:42] 🧩 GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 10:59:42]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 10:59:53]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 11:00:08]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 11:00:16]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 11:00:26] 🧠 Consolidando resumen final ...
# [2025-12-30 11:01:00] ✅ Resumen final listo | 0.6 min
# [2025-12-30 11:01:00] ⏱️ Resumen total: 1.3 min
# [2025-12-30 11:01:00] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:01:00] 🧹 Video local eliminado: GESTIÓN DE LA CALIDAD - 55550_25P05 - 55556_25V05 - 55558_25V05 - 55560_25V05 - 55562_25V05 - 55564 - 2025_12_03 19_45 GMT-05_00 - Recording.mp4
# [2025-12-30 11:01:00] ==========================================================================================
# [2025-12-30 11:01:00] [19/139] ▶️ GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 11:01:00] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 11:01:32] ✅ Descargado: C:\videos_clases_s3\GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 11:01:32] ⏱️ Descarga: 0.5 min
# [2025-12-30 11:01:32] 🎧 Transcribiendo: GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:03:38] ✅ TXT guardado: GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.txt (44499 chars) | 2.1 min
# [2025-12-30 11:03:38] 🧩 GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 11:03:38]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 11:04:11]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 11:04:21]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 11:04:34] 🧠 Consolidando resumen final ...
# [2025-12-30 11:05:19] ✅ Resumen final listo | 0.8 min
# [2025-12-30 11:05:19] ⏱️ Resumen total: 1.7 min
# [2025-12-30 11:05:19] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:05:19] 🧹 Video local eliminado: GRUPO 1 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 18_12 GMT-05_00 - Recording.mp4
# [2025-12-30 11:05:19] ==========================================================================================
# [2025-12-30 11:05:19] [20/139] ▶️ GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:05:19] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:05:54] ✅ Descargado: C:\videos_clases_s3\GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:05:54] ⏱️ Descarga: 0.6 min
# [2025-12-30 11:05:54] 🎧 Transcribiendo: GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:08:24] ✅ TXT guardado: GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.txt (46956 chars) | 2.5 min
# [2025-12-30 11:08:24] 🧩 GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 11:08:24]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 11:08:47]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 11:08:57]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 11:09:10] 🧠 Consolidando resumen final ...
# [2025-12-30 11:09:53] ✅ Resumen final listo | 0.7 min
# [2025-12-30 11:09:53] ⏱️ Resumen total: 1.5 min
# [2025-12-30 11:09:53] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:09:53] 🧹 Video local eliminado: GRUPO 2 LOGICA PARA ESCUELA DE INGENIERIA - 2025_12_03 19_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:09:53] ==========================================================================================
# [2025-12-30 11:09:53] [21/139] ▶️ Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4
# [2025-12-30 11:09:53] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4
# [2025-12-30 11:10:53] ✅ Descargado: C:\videos_clases_s3\Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4
# [2025-12-30 11:10:53] ⏱️ Descarga: 1.0 min
# [2025-12-30 11:10:53] 🎧 Transcribiendo: Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:14:23] ✅ TXT guardado: Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.txt (87541 chars) | 3.5 min
# [2025-12-30 11:14:23] 🧩 Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4: 5 fragmentos
# [2025-12-30 11:14:23]    ↳ Ollama fragmento 1/5 ...
# [2025-12-30 11:14:33]    ↳ Ollama fragmento 2/5 ...
# [2025-12-30 11:14:47]    ↳ Ollama fragmento 3/5 ...
# [2025-12-30 11:14:53] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 3.0s
# [2025-12-30 11:15:02]    ↳ Ollama fragmento 4/5 ...
# [2025-12-30 11:15:12]    ↳ Ollama fragmento 5/5 ...
# [2025-12-30 11:15:24] 🧠 Consolidando resumen final ...
# [2025-12-30 11:16:02] ✅ Resumen final listo | 0.6 min
# [2025-12-30 11:16:02] ⏱️ Resumen total: 1.7 min
# [2025-12-30 11:16:02] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:16:02] 🧹 Video local eliminado: Gerencia del Servicio - 2025_12_03 20_03 GMT-05_00 - Recording.mp4
# [2025-12-30 11:16:02] ==========================================================================================
# [2025-12-30 11:16:02] [22/139] ▶️ Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4
# [2025-12-30 11:16:02] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4
# [2025-12-30 11:16:38] ✅ Descargado: C:\videos_clases_s3\Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4
# [2025-12-30 11:16:38] ⏱️ Descarga: 0.6 min
# [2025-12-30 11:16:38] 🎧 Transcribiendo: Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:19:00] ✅ TXT guardado: Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.txt (56016 chars) | 2.4 min
# [2025-12-30 11:19:00] 🧩 Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 11:19:00]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 11:20:00] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.2s
# [2025-12-30 11:21:07] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 4.6s
# [2025-12-30 11:21:50] ⚠️ Ollama error (intento 3/3): Ollama devolvió respuesta sin JSON válido. | reintento en 9.0s
# [2025-12-30 11:21:59] ❌ Error procesando Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4: Falló Ollama tras 3 intentos. Último error: Ollama devolvió respuesta sin JSON válido.
# [2025-12-30 11:21:59] 🧹 Video local eliminado: Gestión documental y manejo de la información - 2025_12_03 18_16 GMT-05_00 - Recording.mp4
# [2025-12-30 11:21:59] ==========================================================================================
# [2025-12-30 11:21:59] [23/139] ▶️ HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 11:21:59] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 11:22:30] ✅ Descargado: C:\videos_clases_s3\HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 11:22:30] ⏱️ Descarga: 0.5 min
# [2025-12-30 11:22:30] 🎧 Transcribiendo: HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:29:31] ✅ TXT guardado: HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.txt (67885 chars) | 7.0 min
# [2025-12-30 11:29:31] 🧩 HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 11:29:31]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 11:29:39]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 11:29:47]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 11:30:04]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 11:30:17] 🧠 Consolidando resumen final ...
# [2025-12-30 11:30:59] ✅ Resumen final listo | 0.7 min
# [2025-12-30 11:30:59] ⏱️ Resumen total: 1.5 min
# [2025-12-30 11:30:59] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:30:59] 🧹 Video local eliminado: HABILIDADES COMUNICATIVAS_50101_56661_ - 2025_12_03 18_05 GMT-05_00 - Recording.mp4
# [2025-12-30 11:30:59] ==========================================================================================
# [2025-12-30 11:30:59] [24/139] ▶️ HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 11:30:59] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 11:31:22] ✅ Descargado: C:\videos_clases_s3\HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 11:31:22] ⏱️ Descarga: 0.4 min
# [2025-12-30 11:31:22] 🎧 Transcribiendo: HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:37:25] ✅ TXT guardado: HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.txt (61093 chars) | 6.0 min
# [2025-12-30 11:37:25] 🧩 HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 11:37:25]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 11:37:50]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 11:38:03]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 11:38:16]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 11:38:27] 🧠 Consolidando resumen final ...
# [2025-12-30 11:38:50] ✅ Resumen final listo | 0.4 min
# [2025-12-30 11:38:50] ⏱️ Resumen total: 1.4 min
# [2025-12-30 11:38:50] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:38:50] 🧹 Video local eliminado: HABILIDADES COMUNICATIVAS_56663_56697_PRIMER BLOQUE_25V06 - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 11:38:50] ==========================================================================================
# [2025-12-30 11:38:50] [25/139] ▶️ HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 11:38:50] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 11:39:37] ✅ Descargado: C:\videos_clases_s3\HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 11:39:37] ⏱️ Descarga: 0.8 min
# [2025-12-30 11:39:37] 🎧 Transcribiendo: HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:44:26] ✅ TXT guardado: HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.txt (43890 chars) | 4.8 min
# [2025-12-30 11:44:26] 🧩 HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 11:44:26]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 11:45:29] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.9s
# [2025-12-30 11:46:35] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 5.0s
# [2025-12-30 11:47:44] ⚠️ Ollama error (intento 3/3): Ollama devolvió respuesta sin JSON válido. | reintento en 8.3s
# [2025-12-30 11:47:52] ❌ Error procesando HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4: Falló Ollama tras 3 intentos. Último error: Ollama devolvió respuesta sin JSON válido.
# [2025-12-30 11:47:52] 🧹 Video local eliminado: HABILIDADES DE COMUNICACIÓN 55596 - 55523 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 11:47:52] ==========================================================================================
# [2025-12-30 11:47:52] [26/139] ▶️ HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:47:52] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:48:23] ✅ Descargado: C:\videos_clases_s3\HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:48:23] ⏱️ Descarga: 0.5 min
# [2025-12-30 11:48:23] 🎧 Transcribiendo: HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 11:54:56] ✅ TXT guardado: HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.txt (61929 chars) | 6.6 min
# [2025-12-30 11:54:56] 🧩 HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4: 4 fragmentos
# [2025-12-30 11:54:56]    ↳ Ollama fragmento 1/4 ...
# [2025-12-30 11:55:14]    ↳ Ollama fragmento 2/4 ...
# [2025-12-30 11:55:36]    ↳ Ollama fragmento 3/4 ...
# [2025-12-30 11:55:57] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.9s
# [2025-12-30 11:56:20]    ↳ Ollama fragmento 4/4 ...
# [2025-12-30 11:56:29] 🧠 Consolidando resumen final ...
# [2025-12-30 11:57:07] ✅ Resumen final listo | 0.6 min
# [2025-12-30 11:57:07] ⏱️ Resumen total: 2.2 min
# [2025-12-30 11:57:07] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording_resumen.json
# [2025-12-30 11:57:07] 🧹 Video local eliminado: HERRAMIENTAS TECNOLOGICAS PARA LA ATENCION CIUDADANA - 2025_12_03 17_46 GMT-05_00 - Recording.mp4
# [2025-12-30 11:57:07] ==========================================================================================
# [2025-12-30 11:57:07] [27/139] ▶️ HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4
# [2025-12-30 11:57:07] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4
# [2025-12-30 11:57:43] ✅ Descargado: C:\videos_clases_s3\HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4
# [2025-12-30 11:57:43] ⏱️ Descarga: 0.6 min
# [2025-12-30 11:57:43] 🎧 Transcribiendo: HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 12:00:09] ✅ TXT guardado: HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.txt (22606 chars) | 2.4 min
# [2025-12-30 12:00:09] 🧩 HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 12:00:09]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 12:00:19]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 12:00:30] 🧠 Consolidando resumen final ...
# [2025-12-30 12:01:06] ✅ Resumen final listo | 0.6 min
# [2025-12-30 12:01:06] ⏱️ Resumen total: 0.9 min
# [2025-12-30 12:01:06] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording_resumen.json
# [2025-12-30 12:01:06] 🧹 Video local eliminado: HISTORIA DEL DISEÑO LATINOAMERICANO Y COLOMBIANO - Encuentro sincrónico - Profesora Laura López - 2025_12_03 18_13 GMT-05_00 - Recording.mp4
# [2025-12-30 12:01:06] ==========================================================================================
# [2025-12-30 12:01:06] [28/139] ▶️ IMPUESTOS  NACIONALES  - 55537 - 56676 (87) - 2025_12_03 19_24 GMT-05_00 - Recording.mp4
# [2025-12-30 12:01:06] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/IMPUESTOS  NACIONALES  - 55537 - 56676 (87) - 2025_12_03 19_24 GMT-05_00 - Recording.mp4
# ...
# [2025-12-30 18:58:47] ✅ TXT guardado: Tecnologias aplicadas (Softwareensalud) grupos 56640-55575-56632   - 2025_12_03 19_51 GMT-05_00 - Recording.txt (58523 chars) | 2.6 min
# [2025-12-30 18:58:47] 🧩 Tecnologias aplicadas (Softwareensalud) grupos 56640-55575-56632   - 2025_12_03 19_51 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 18:58:47]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 18:59:03]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 19:00:11] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.4s
# [2025-12-30 19:00:31]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 19:00:49] 🧠 Consolidando resumen final ...
# [2025-12-30 19:01:19] ✅ Resumen final listo | 0.5 min
# [2025-12-30 19:01:19] ⏱️ Resumen total: 2.5 min
# [2025-12-30 19:01:19] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Tecnologias aplicadas (Softwareensalud) grupos 56640-55575-56632   - 2025_12_03 19_51 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:01:19] 🧹 Video local eliminado: Tecnologias aplicadas (Softwareensalud) grupos 56640-55575-56632   - 2025_12_03 19_51 GMT-05_00 - Recording.mp4
# [2025-12-30 19:01:19] ==========================================================================================
# [2025-12-30 19:01:19] [130/139] ▶️ Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4
# [2025-12-30 19:01:19] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4
# [2025-12-30 19:01:47] ✅ Descargado: C:\videos_clases_s3\Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4
# [2025-12-30 19:01:47] ⏱️ Descarga: 0.5 min
# [2025-12-30 19:01:47] 🎧 Transcribiendo: Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:04:06] ✅ TXT guardado: Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.txt (50970 chars) | 2.3 min
# [2025-12-30 19:04:06] 🧩 Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4: 3 fragmentos
# [2025-12-30 19:04:06]    ↳ Ollama fragmento 1/3 ...
# [2025-12-30 19:04:26]    ↳ Ollama fragmento 2/3 ...
# [2025-12-30 19:04:44]    ↳ Ollama fragmento 3/3 ...
# [2025-12-30 19:05:01] 🧠 Consolidando resumen final ...
# [2025-12-30 19:05:48] ✅ Resumen final listo | 0.8 min
# [2025-12-30 19:05:48] ⏱️ Resumen total: 1.7 min
# [2025-12-30 19:05:48] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:05:48] 🧹 Video local eliminado: Tendencias actuales de la administración pública - 2025_12_03 19_55 GMT-05_00 - Recording.mp4
# [2025-12-30 19:05:48] ==========================================================================================
# [2025-12-30 19:05:48] [131/139] ▶️ Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4
# [2025-12-30 19:05:48] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4
# [2025-12-30 19:05:51] ✅ Descargado: C:\videos_clases_s3\Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4
# [2025-12-30 19:05:51] ⏱️ Descarga: 0.0 min
# [2025-12-30 19:05:51] 🎧 Transcribiendo: Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:05:56] ✅ TXT guardado: Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.txt (159 chars) | 0.1 min
# [2025-12-30 19:05:56] 🧩 Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:06:14] ✅ Resumen (1 paso) listo | 0.3 min
# [2025-12-30 19:06:14] ⏱️ Resumen total: 0.3 min
# [2025-12-30 19:06:14] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:06:14] 🧹 Video local eliminado: Tutoría - Programación Avanzada - 2025_12_03 21_21 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:14] ==========================================================================================
# [2025-12-30 19:06:14] [132/139] ▶️ Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:14] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:19] ✅ Descargado: C:\videos_clases_s3\Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:19] ⏱️ Descarga: 0.1 min
# [2025-12-30 19:06:19] 🎧 Transcribiendo: Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:06:34] ✅ TXT guardado: Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.txt (5030 chars) | 0.3 min
# [2025-12-30 19:06:34] 🧩 Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:06:57] ✅ Resumen (1 paso) listo | 0.4 min
# [2025-12-30 19:06:57] ⏱️ Resumen total: 0.4 min
# [2025-12-30 19:06:57] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:06:57] 🧹 Video local eliminado: Tutoría General Informática y CT - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:57] ==========================================================================================
# [2025-12-30 19:06:57] [133/139] ▶️ VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4
# [2025-12-30 19:06:57] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4
# [2025-12-30 19:07:26] ✅ Descargado: C:\videos_clases_s3\VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4
# [2025-12-30 19:07:26] ⏱️ Descarga: 0.5 min
# [2025-12-30 19:07:26] 🎧 Transcribiendo: VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:09:06] ✅ TXT guardado: VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.txt (16785 chars) | 1.7 min
# [2025-12-30 19:09:06] 🧩 VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:09:18] ✅ Resumen (1 paso) listo | 0.2 min
# [2025-12-30 19:09:18] ⏱️ Resumen total: 0.2 min
# [2025-12-30 19:09:18] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:09:19] 🧹 Video local eliminado: VIRTUAL ENGLISH - PRE-INTERMEDIATE 3_ - 2025_12_03 18_09 GMT-05_00 - Recording.mp4
# [2025-12-30 19:09:19] ==========================================================================================
# [2025-12-30 19:09:19] [134/139] ▶️ VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4
# [2025-12-30 19:09:19] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4
# [2025-12-30 19:09:52] ✅ Descargado: C:\videos_clases_s3\VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4
# [2025-12-30 19:09:52] ⏱️ Descarga: 0.6 min
# [2025-12-30 19:09:52] 🎧 Transcribiendo: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:11:32] ✅ TXT guardado: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.txt (21469 chars) | 1.7 min
# [2025-12-30 19:11:32] 🧩 VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 19:11:32]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 19:11:47]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 19:11:58] 🧠 Consolidando resumen final ...
# [2025-12-30 19:12:22] ✅ Resumen final listo | 0.4 min
# [2025-12-30 19:12:22] ⏱️ Resumen total: 0.8 min
# [2025-12-30 19:12:22] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:12:22] 🧹 Video local eliminado: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 18_02 GMT-05_00 - Recording.mp4
# [2025-12-30 19:12:22] ==========================================================================================
# [2025-12-30 19:12:22] [135/139] ▶️ VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4
# [2025-12-30 19:12:22] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4
# [2025-12-30 19:12:41] ✅ Descargado: C:\videos_clases_s3\VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4
# [2025-12-30 19:12:41] ⏱️ Descarga: 0.3 min
# [2025-12-30 19:12:41] 🎧 Transcribiendo: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:13:33] ✅ TXT guardado: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.txt (15438 chars) | 0.9 min
# [2025-12-30 19:13:33] 🧩 VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:13:42] ✅ Resumen (1 paso) listo | 0.2 min
# [2025-12-30 19:13:42] ⏱️ Resumen total: 0.2 min
# [2025-12-30 19:13:42] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:13:42] 🧹 Video local eliminado: VIRTUAL ENGLISH – BEGINNER 1_50501_25I06 - 2025_12_03 19_57 GMT-05_00 - Recording.mp4
# [2025-12-30 19:13:42] ==========================================================================================
# [2025-12-30 19:13:42] [136/139] ▶️ VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:13:42] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:14:15] ✅ Descargado: C:\videos_clases_s3\VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:14:15] ⏱️ Descarga: 0.5 min
# [2025-12-30 19:14:15] 🎧 Transcribiendo: VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:15:55] ✅ TXT guardado: VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.txt (16857 chars) | 1.7 min
# [2025-12-30 19:15:55] 🧩 VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:16:12] ✅ Resumen (1 paso) listo | 0.3 min
# [2025-12-30 19:16:12] ⏱️ Resumen total: 0.3 min
# [2025-12-30 19:16:12] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:16:12] 🧹 Video local eliminado: VIRTUAL ENGLISH- BEGINNER 1_50506_25I06 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:16:12] ==========================================================================================
# [2025-12-30 19:16:12] [137/139] ▶️ VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:16:12] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:16:45] ✅ Descargado: C:\videos_clases_s3\VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:16:45] ⏱️ Descarga: 0.6 min
# [2025-12-30 19:16:45] 🎧 Transcribiendo: VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:18:19] ✅ TXT guardado: VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.txt (13892 chars) | 1.6 min
# [2025-12-30 19:18:19] 🧩 VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4: 1 fragmentos
# [2025-12-30 19:18:27] ⚠️ Ollama error (intento 1/3): Ollama devolvió respuesta sin JSON válido. | reintento en 2.0s
# [2025-12-30 19:19:34] ⚠️ Ollama error (intento 2/3): Ollama devolvió respuesta sin JSON válido. | reintento en 4.2s
# [2025-12-30 19:19:53] ✅ Resumen (1 paso) listo | 1.6 min
# [2025-12-30 19:19:53] ⏱️ Resumen total: 1.6 min
# [2025-12-30 19:19:53] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:19:53] 🧹 Video local eliminado: VIRTUAL ENGLISH- BEGINNER 3 _ 25I06 _25PI6 - 2025_12_03 19_50 GMT-05_00 - Recording.mp4
# [2025-12-30 19:19:53] ==========================================================================================
# [2025-12-30 19:19:53] [138/139] ▶️ matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4
# [2025-12-30 19:19:53] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4
# [2025-12-30 19:20:19] ✅ Descargado: C:\videos_clases_s3\matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4
# [2025-12-30 19:20:19] ⏱️ Descarga: 0.4 min
# [2025-12-30 19:20:19] 🎧 Transcribiendo: matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:22:18] ✅ TXT guardado: matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.txt (32814 chars) | 2.0 min
# [2025-12-30 19:22:18] 🧩 matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 19:22:18]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 19:22:25]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 19:22:39] 🧠 Consolidando resumen final ...
# [2025-12-30 19:23:19] ✅ Resumen final listo | 0.7 min
# [2025-12-30 19:23:19] ⏱️ Resumen total: 1.0 min
# [2025-12-30 19:23:19] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:23:19] 🧹 Video local eliminado: matematica discreta - 2025_12_03 18_01 GMT-05_00 - Recording.mp4
# [2025-12-30 19:23:19] ==========================================================================================
# [2025-12-30 19:23:19] [139/139] ▶️ matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4
# [2025-12-30 19:23:19] ⬇️ Descargando: s3://cun-transcribe-five9/Videos_clase_Profesores/video_12_04_25a/matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4
# [2025-12-30 19:23:37] ✅ Descargado: C:\videos_clases_s3\matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4
# [2025-12-30 19:23:37] ⏱️ Descarga: 0.3 min
# [2025-12-30 19:23:37] 🎧 Transcribiendo: matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4 (batch_size=16) ...
# [2025-12-30 19:25:41] ✅ TXT guardado: matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.txt (34811 chars) | 2.1 min
# [2025-12-30 19:25:41] 🧩 matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4: 2 fragmentos
# [2025-12-30 19:25:41]    ↳ Ollama fragmento 1/2 ...
# [2025-12-30 19:25:46]    ↳ Ollama fragmento 2/2 ...
# [2025-12-30 19:26:06] 🧠 Consolidando resumen final ...
# [2025-12-30 19:26:40] ✅ Resumen final listo | 0.6 min
# [2025-12-30 19:26:40] ⏱️ Resumen total: 1.0 min
# [2025-12-30 19:26:40] 💾 JSON guardado: C:\resumenes_clases_json_s3\12_04_25a\matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording_resumen.json
# [2025-12-30 19:26:40] 🧹 Video local eliminado: matematica discreta 2  - 2025_12_03 19_44 GMT-05_00 - Recording.mp4
